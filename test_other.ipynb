# %%
import websocket
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("/Users/augustingoudet/.secret/code_file") #Finnhub Key

company = "XOM" #Company Ticker
api_key = keys ['finnhub'] #api_key

# %% [markdown]
# ## ceo compensation

# %%
url = "https://finnhub.io/api/v1/stock/ceo-compensation?symbol={}&token={}".format(company, api_key) #url
req = requests.get(url)

# %%
salary = req.json()

# %%
ceo_pay = pd.DataFrame(salary.items(), columns =['Features', 'Value'])

# %%
ceo_pay
# Out:
#                Features                  Value
# 0                 bonus                      0
# 1           companyName  Starbucks Corporation
# 2              location            Seattle, WA
# 3                  name          Kevin Johnson
# 4   nonEquityIncentives                 960000
# 5          optionAwards                4233929
# 6             otherComp                  67036
# 7    pensionAndDeferred                      0
# 8                salary                1461533
# 9           stockAwards                6659982
# 10               symbol                   SBUX
# 11                total               13382480
# 12                 year                   2018

# %% [markdown]
# ## board members / executive

# %%
url1 = "https://finnhub.io/api/v1/stock/executive?symbol={}&token={}".format(company, api_key) #url
req1 = requests.get(url1)

# %%
list = req1.json()

# %%
print(req1.json())
# Out:
# {'executive': [{'age': 72, 'name': 'Myron E. Ullman', 'since': 2018, 'title': 'Chairman of the Board'}, {'age': 58, 'name': 'Kevin Ronald Johnson', 'since': 2017, 'title': 'President, Chief Executive Officer, Director'}, {'age': 50, 'name': 'Mellody L. Hobson', 'since': 2018, 'title': 'Vice Chairman of the Board'}, {'age': 56, 'name': 'Patrick J. Grismer', 'since': 2018, 'title': 'Chief Financial Officer, Executive Vice President'}, {'age': 58, 'name': 'John Culver', 'since': 2017, 'title': 'Group President - International and Channels'}, {'age': 56, 'name': 'Rosalind G. Brewer', 'since': 2017, 'title': 'Chief Operating Officer, Group President - Americas, Director'}, {'age': 49, 'name': 'Rachel A. Gonzalez', 'since': 2018, 'title': 'Executive Vice President, General Counsel, Secretary'}, {'age': 60, 'name': 'Lucy Lee Helm', 'since': 2017, 'title': 'executive vice president, chief partner officer'}, {'age': 47, 'name': 'Jill L. Walker', 'since': 2019, 'title': 'Senior Vice President, Corporate Financial Services, Chief Accounting Officer'}, {'age': 52, 'name': 'Richard E. Allison', 'since': 2019, 'title': 'Independent Director'}, {'age': 47, 'name': 'Andrew M. Campion', 'since': 2019, 'title': 'Independent Director'}, {'age': 57, 'name': 'Mary N. Dillon', 'since': 2016, 'title': 'Independent Director'}, {'age': '', 'name': 'Isabel Ge Mahe', 'since': 2019, 'title': 'Independent Director'}, {'age': 50, 'name': 'Jorgen Vig Knudstorp', 'since': 2017, 'title': 'Independent Director'}, {'age': 52, 'name': 'Satya Nadella', 'since': 2017, 'title': 'Independent Director'}, {'age': 50, 'name': 'Joshua Cooper Ramo', 'since': 2011, 'title': 'Independent Director'}, {'age': 37, 'name': 'Clara Shih', 'since': 2011, 'title': 'Independent Director'}, {'age': 68, 'name': 'Javier G. Teruel', 'since': 2005, 'title': 'Independent Director'}], 'symbol': 'SBUX'}

# %%
df = pd.DataFrame(req1.json())

# %%
df2 = json_normalize(df['executive'])
df2
# Out:
#    age                  name  since  \
# 0   72       Myron E. Ullman   2018
# 1   58  Kevin Ronald Johnson   2017
# 2   50     Mellody L. Hobson   2018
# 3   56    Patrick J. Grismer   2018
# 4   58           John Culver   2017
# 5   56    Rosalind G. Brewer   2017
# 6   49    Rachel A. Gonzalez   2018
# 7   60         Lucy Lee Helm   2017
# 8   47        Jill L. Walker   2019
# 9   52    Richard E. Allison   2019
# 10  47     Andrew M. Campion   2019
# 11  57        Mary N. Dillon   2016
# 12            Isabel Ge Mahe   2019
# 13  50  Jorgen Vig Knudstorp   2017
# 14  52         Satya Nadella   2017
# 15  50    Joshua Cooper Ramo   2011
# 16  37            Clara Shih   2011
# 17  68      Javier G. Teruel   2005
#
#                                                 title
# 0                               Chairman of the Board
# 1        President, Chief Executive Officer, Director
# 2                          Vice Chairman of the Board
# 3   Chief Financial Officer, Executive Vice President
# 4        Group President - International and Channels
# 5   Chief Operating Officer, Group President - Ame...
# 6   Executive Vice President, General Counsel, Sec...
# 7     executive vice president, chief partner officer
# 8   Senior Vice President, Corporate Financial Ser...
# 9                                Independent Director
# 10                               Independent Director
# 11                               Independent Director
# 12                               Independent Director
# 13                               Independent Director
# 14                               Independent Director
# 15                               Independent Director
# 16                               Independent Director
# 17                               Independent Director

# %%
rows = []

for data in req1:
    data_row = data['name']
    time = data['name']
    
    for row in data_row: 
        row['name'] = time
        rows.append(row)
        
df = pd.DataFrame(rows)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-24ea894e305e> in <module>
#       2
#       3 for data in req1:
# ----> 4     data_row = data['name']
#       5     time = data['name']
#       6
#
# TypeError: byte indices must be integers or slices, not str

# %% [markdown]
# ## analyst recommendation

# %%
url2 = "https://finnhub.io/api/v1/stock/recommendation?symbol={}&token={}".format(company, api_key) #url
req2 = requests.get(url2)

# %%
print(req2.json())
# Out:
# [{'buy': 3, 'hold': 10, 'period': '2020-03-01', 'sell': 2, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2020-02-01', 'sell': 0, 'strongBuy': 0, 'strongSell': 1, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2020-01-01', 'sell': 0, 'strongBuy': 0, 'strongSell': 1, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-12-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-11-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-10-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-09-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-08-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-07-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-06-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-05-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-04-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-03-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-02-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}, {'buy': 3, 'hold': 10, 'period': '2019-01-01', 'sell': 1, 'strongBuy': 2, 'strongSell': 0, 'symbol': 'COTY'}]

# %% [markdown]
# ## price target

# %%
url3 = "https://finnhub.io/api/v1/stock/price-target?symbol={}&token={}".format(company, api_key) #url
req3 = requests.get(url3)

# %%
print(req3.json())
# Out:
# {'lastUpdated': '2020-03-28 00:00:00', 'symbol': 'SBUX', 'targetHigh': 105, 'targetLow': 70, 'targetMean': 88.82, 'targetMedian': 90}

# %% [markdown]
# ## Stock Upgrade / Downgrade

# %%
url4 = "https://finnhub.io/api/v1/stock/upgrade-downgrade?symbol={}&token={}".format(company, api_key) #url
req4 = requests.get(url4) 
status = pd.DataFrame(req4.json())

# %%
status
# Out:
#    symbol   gradeTime             company       fromGrade         toGrade  \
# 0    SBUX  1578528000            Barclays    Equal-Weight      Overweight
# 1    SBUX  1576713600      Morgan Stanley                    Equal-Weight
# 2    SBUX  1574208000                Citi                             Buy
# 3    SBUX  1572480000     Bank of America                             Buy
# 4    SBUX  1564358400                 UBS                         Neutral
# 5    SBUX  1564358400           JP Morgan      Overweight         Neutral
# 6    SBUX  1564358400       Goldman Sachs                             Buy
# 7    SBUX  1564358400               Baird      Outperform         Neutral
# 8    SBUX  1564099200             Wedbush                         Neutral
# 9    SBUX  1564099200     Stifel Nicolaus                            Hold
# 10   SBUX  1564099200      Stephens & Co.                    Equal-Weight
# 11   SBUX  1564099200      Morgan Stanley                    Equal-Weight
# 12   SBUX  1564099200             KeyBanc                      Overweight
# 13   SBUX  1564099200               Baird                      Outperform
# 14   SBUX  1563408000      Morgan Stanley                    Equal-Weight
# 15   SBUX  1562803200         Oppenheimer                      Outperform
# 16   SBUX  1561420800       Credit Suisse                      Outperform
# 17   SBUX  1560297600  Evercore ISI Group                         In-Line
# 18   SBUX  1560124800       Piper Jaffray                         Neutral
# 19   SBUX  1557100800           Citigroup             Buy             Buy
# 20   SBUX  1554681600                 UBS             Buy         Neutral
# 21   SBUX  1547164800       Goldman Sachs             Buy         Neutral
# 22   SBUX  1544745600         Wells Fargo      Outperform      Outperform
# 23   SBUX  1541980800           Citigroup             Buy             Buy
# 24   SBUX  1541980800               Argus            Hold             Buy
# 25   SBUX  1541376000              Mizuho         Neutral             Buy
# 26   SBUX  1541116800             Wedbush         Neutral         Neutral
# 27   SBUX  1541116800         BMO Capital  Market Perform  Market Perform
# 28   SBUX  1541116800            Barclays    Equal-Weight    Equal-Weight
# 29   SBUX  1541116800     Bank of America             Buy             Buy
# 30   SBUX  1541116800               Baird      Outperform      Outperform
# 31   SBUX  1539734400         Wells Fargo      Outperform      Outperform
# 32   SBUX  1514332800   Tigress Financial                             Buy
#
#    action
# 0      up
# 1    main
# 2    main
# 3    main
# 4    main
# 5    down
# 6    init
# 7    down
# 8    main
# 9    main
# 10   main
# 11   main
# 12   main
# 13   main
# 14   main
# 15   main
# 16   init
# 17   init
# 18   main
# 19   main
# 20   down
# 21   down
# 22   reit
# 23   main
# 24     up
# 25     up
# 26   main
# 27   main
# 28   main
# 29   main
# 30   main
# 31   main
# 32   init

# %% [markdown]
# ### Peers

# %%
url5 = "https://finnhub.io/api/v1/stock/peers?symbol={}&token={}".format(company, api_key) #url
req5 = requests.get(url5)

# %%
print(req5.json())
# Out:
# ['EL', 'EEIG', 'COTY', 'IPAR', 'EPC', 'USNA', 'NUS', 'MED', 'BRBR', 'REV']

# %% [markdown]
# ## Revenue Estimates

# %%
url6 = "https://finnhub.io/api/v1/stock/revenue-estimate?symbol={}&token={}".format(company, api_key) #url
req6 = requests.get(url6) 
rev = pd.DataFrame(req6.json())
rev1 = json_normalize(rev['data'])
rev1
# Out:
#      numberAnalysts      period  revenueAvg  revenueHigh  revenueLow
# 0                15  2020-12-31  7504547000   7642071000  7139560000
# 1                24  2020-09-30  6906355830   7301800000  6153200000
# 2                24  2020-06-30  6323203390   7275000000  4300300000
# 3                23  2020-06-30  7145390000   7349000000  6852150000
# 4                24  2020-03-31  6126779300   6758000000  5171400000
# ..              ...         ...         ...          ...         ...
# 97                1  1997-03-31   214904000    214904000   214904000
# 98                1  1996-12-31   239019000    239019000   239019000
# 99                3  1996-09-30   193896670    197200000   191000000
# 100               1  1996-06-30   181600000    181600000   181600000
# 101               1  1996-03-31   151600000    151600000   151600000
#
# [102 rows x 5 columns]

# %% [markdown]
# ## Earnings Estimate

# %%
url7 = "https://finnhub.io/api/v1/stock/eps-estimate?symbol={}&token={}".format(company, api_key) #url
req7 = requests.get(url7) 
print(req7.json())
# Out:
# {'data': [{'epsAvg': 0.83819, 'epsHigh': 0.96, 'epsLow': 0.74, 'numberAnalysts': 18, 'period': '2020-12-31'}, {'epsAvg': 0.71232, 'epsHigh': 0.85, 'epsLow': 0.36, 'numberAnalysts': 28, 'period': '2020-09-30'}, {'epsAvg': 0.54689, 'epsHigh': 0.8340000000000001, 'epsLow': -0.35, 'numberAnalysts': 28, 'period': '2020-06-30'}, {'epsAvg': 0.43682, 'epsHigh': 0.675, 'epsLow': 0.13, 'numberAnalysts': 28, 'period': '2020-03-31'}, {'epsAvg': 0.75864, 'epsHigh': 0.81, 'epsLow': 0.73, 'numberAnalysts': 25, 'period': '2019-12-31'}, {'epsAvg': 0.69867, 'epsHigh': 0.72, 'epsLow': 0.69, 'numberAnalysts': 27, 'period': '2019-09-30'}, {'epsAvg': 0.72407, 'epsHigh': 0.75, 'epsLow': 0.7, 'numberAnalysts': 28, 'period': '2019-06-30'}, {'epsAvg': 0.56313, 'epsHigh': 0.58, 'epsLow': 0.54, 'numberAnalysts': 25, 'period': '2019-03-31'}, {'epsAvg': 0.6483899999999999, 'epsHigh': 0.68, 'epsLow': 0.6, 'numberAnalysts': 28, 'period': '2018-12-31'}, {'epsAvg': 0.59904, 'epsHigh': 0.63, 'epsLow': 0.57, 'numberAnalysts': 28, 'period': '2018-09-30'}, {'epsAvg': 0.60763, 'epsHigh': 0.68, 'epsLow': 0.58, 'numberAnalysts': 27, 'period': '2018-06-30'}, {'epsAvg': 0.53004, 'epsHigh': 0.56, 'epsLow': 0.51, 'numberAnalysts': 27, 'period': '2018-03-31'}, {'epsAvg': 0.57145, 'epsHigh': 0.61, 'epsLow': 0.55, 'numberAnalysts': 29, 'period': '2017-12-31'}, {'epsAvg': 0.54638, 'epsHigh': 0.57, 'epsLow': 0.5329999999999999, 'numberAnalysts': 29, 'period': '2017-09-30'}, {'epsAvg': 0.5511, 'epsHigh': 0.56, 'epsLow': 0.54, 'numberAnalysts': 29, 'period': '2017-06-30'}, {'epsAvg': 0.44861999999999996, 'epsHigh': 0.46, 'epsLow': 0.44, 'numberAnalysts': 29, 'period': '2017-03-31'}, {'epsAvg': 0.5199699999999999, 'epsHigh': 0.53, 'epsLow': 0.51, 'numberAnalysts': 29, 'period': '2016-12-31'}, {'epsAvg': 0.54818, 'epsHigh': 0.5539999999999999, 'epsLow': 0.54, 'numberAnalysts': 28, 'period': '2016-09-30'}, {'epsAvg': 0.48656000000000005, 'epsHigh': 0.5, 'epsLow': 0.478, 'numberAnalysts': 27, 'period': '2016-06-30'}, {'epsAvg': 0.38989, 'epsHigh': 0.4, 'epsLow': 0.37799999999999995, 'numberAnalysts': 26, 'period': '2016-03-31'}, {'epsAvg': 0.45008000000000004, 'epsHigh': 0.46, 'epsLow': 0.44, 'numberAnalysts': 24, 'period': '2015-12-31'}, {'epsAvg': 0.43392, 'epsHigh': 0.45, 'epsLow': 0.425, 'numberAnalysts': 25, 'period': '2015-09-30'}, {'epsAvg': 0.40836999999999996, 'epsHigh': 0.42, 'epsLow': 0.395, 'numberAnalysts': 27, 'period': '2015-06-30'}, {'epsAvg': 0.32633, 'epsHigh': 0.35, 'epsLow': 0.31, 'numberAnalysts': 26, 'period': '2015-03-31'}, {'epsAvg': 0.40146, 'epsHigh': 0.406, 'epsLow': 0.395, 'numberAnalysts': 25, 'period': '2014-12-31'}, {'epsAvg': 0.37125, 'epsHigh': 0.375, 'epsLow': 0.365, 'numberAnalysts': 24, 'period': '2014-09-30'}, {'epsAvg': 0.33138, 'epsHigh': 0.337, 'epsLow': 0.325, 'numberAnalysts': 28, 'period': '2014-06-30'}, {'epsAvg': 0.27837, 'epsHigh': 0.299, 'epsLow': 0.27, 'numberAnalysts': 27, 'period': '2014-03-31'}, {'epsAvg': 0.34535, 'epsHigh': 0.355, 'epsLow': 0.335, 'numberAnalysts': 30, 'period': '2013-12-31'}, {'epsAvg': 0.2989, 'epsHigh': 0.31, 'epsLow': 0.28, 'numberAnalysts': 28, 'period': '2013-09-30'}, {'epsAvg': 0.26574000000000003, 'epsHigh': 0.275, 'epsLow': 0.255, 'numberAnalysts': 29, 'period': '2013-06-30'}, {'epsAvg': 0.24111, 'epsHigh': 0.26, 'epsLow': 0.235, 'numberAnalysts': 31, 'period': '2013-03-31'}, {'epsAvg': 0.28623000000000004, 'epsHigh': 0.295, 'epsLow': 0.275, 'numberAnalysts': 29, 'period': '2012-12-31'}, {'epsAvg': 0.22375, 'epsHigh': 0.235, 'epsLow': 0.21, 'numberAnalysts': 28, 'period': '2012-09-30'}, {'epsAvg': 0.22625, 'epsHigh': 0.24, 'epsLow': 0.22, 'numberAnalysts': 28, 'period': '2012-06-30'}, {'epsAvg': 0.19572, 'epsHigh': 0.215, 'epsLow': 0.185, 'numberAnalysts': 28, 'period': '2012-03-31'}, {'epsAvg': 0.24334, 'epsHigh': 0.26, 'epsLow': 0.23, 'numberAnalysts': 27, 'period': '2011-12-31'}, {'epsAvg': 0.18212, 'epsHigh': 0.19, 'epsLow': 0.17, 'numberAnalysts': 26, 'period': '2011-09-30'}, {'epsAvg': 0.16913, 'ep ...

# %% [markdown]
# ## Investor Ownership

# %%
url8 = "https://finnhub.io/api/v1/stock/investor-ownership?symbol={}&token={}".format(company, api_key) #url
req8 = requests.get(url8) 
# print(req8.json())
own = req8.json()

# %%
ownership = pd.DataFrame(own.items(), columns =['Features', 'Value'])
# print(req8.json())
owner = pd.DataFrame(req8.json())
owner1 = json_normalize(owner['ownership'])

# %%
owner1
# Out:
#                                             name     share turnover  \
# 0                       The Vanguard Group, Inc.  89255544      LOW
# 1    BlackRock Institutional Trust Company, N.A.  56630824      LOW
# 2              State Street Global Advisors (US)  52101680      LOW
# 3              Magellan Asset Management Limited  32036678      LOW
# 4               Geode Capital Management, L.L.C.  18603872      LOW
# ..                                           ...       ...      ...
# 995                    Banque Cantonale Vaudoise     26946     HIGH
# 996                       Wimmer Associates, LLC     26789      LOW
# 997              Merriman Wealth Management, LLC     26760
# 998              Fieldpoint Private Bank & Trust     26719      LOW
# 999                   Swisscanto Fondsleitung AG     26719      LOW
#
#      turnoverPercent   change  filingDate
# 0             6.6903  -571290  2019-12-31
# 1            12.1429 -1016587  2019-12-31
# 2             5.8047  -169439  2019-12-31
# 3            36.0387  3553788  2019-12-31
# 4             9.2443   161755  2019-12-31
# ..               ...      ...         ...
# 995         195.4212    26946  2019-12-31
# 996           8.4039     -130  2019-12-31
# 997           0.0000     1083  2019-12-31
# 998          26.7934    11857  2019-12-31
# 999          19.6619      166  2019-11-30
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Fund Ownership

# %%
url9 = "https://finnhub.io/api/v1/stock/fund-ownership?symbol={}&token={}".format(company, api_key) #url
req9 = requests.get(url9)
fdowner = pd.DataFrame(req9.json())
fdowner1 = json_normalize(owner['ownership'])
fdowner1
# Out:
#                                             name     share turnover  \
# 0                       The Vanguard Group, Inc.  89255544      LOW
# 1    BlackRock Institutional Trust Company, N.A.  56630824      LOW
# 2              State Street Global Advisors (US)  52101680      LOW
# 3              Magellan Asset Management Limited  32036678      LOW
# 4               Geode Capital Management, L.L.C.  18603872      LOW
# ..                                           ...       ...      ...
# 995                    Banque Cantonale Vaudoise     26946     HIGH
# 996                       Wimmer Associates, LLC     26789      LOW
# 997              Merriman Wealth Management, LLC     26760
# 998              Fieldpoint Private Bank & Trust     26719      LOW
# 999                   Swisscanto Fondsleitung AG     26719      LOW
#
#      turnoverPercent   change  filingDate
# 0             6.6903  -571290  2019-12-31
# 1            12.1429 -1016587  2019-12-31
# 2             5.8047  -169439  2019-12-31
# 3            36.0387  3553788  2019-12-31
# 4             9.2443   161755  2019-12-31
# ..               ...      ...         ...
# 995         195.4212    26946  2019-12-31
# 996           8.4039     -130  2019-12-31
# 997           0.0000     1083  2019-12-31
# 998          26.7934    11857  2019-12-31
# 999          19.6619      166  2019-11-30
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## performance metrics

# %%
url9 = "https://finnhub.io/api/v1/stock/metric?symbol={}&metric=growth&token={}".format(company, api_key) #url
req9 = requests.get(url9) 
print(req9.json())
# Out:
# {'metric': {'bookValueShareGrowth5Y': '', 'capitalSpendingGrowth5Y': 9.24799, 'dividendGrowthRate5Y': 21.64402, 'ebitdaCagr5Y': 8.8923, 'ebitdaInterimCagr5Y': 8.43955, 'epsGrowth3Y': 15.47836, 'epsGrowth5Y': 16.58506, 'epsGrowthQuarterlyYoy': 22.54832, 'epsGrowthTTMYoy': 35.01014, 'focfCagr5Y': '', 'netMarginGrowth5Y': 1.52589, 'revenueGrowth3Y': 7.53777, 'revenueGrowth5Y': 10.01599, 'revenueGrowthQuarterlyYoy': 7.00167, 'revenueGrowthTTMYoy': 6.70375, 'revenueShareGrowth5Y': 14.8078, 'tbvCagr5Y': '', 'totalDebtCagr5Y': 40.38108}, 'metricType': 'growth', 'symbol': 'SBUX'}

# %%
perf = pd.DataFrame(req9.json())
perf
# Out:
#                             metric metricType symbol
# bookValueShareGrowth5Y                 growth   SBUX
# capitalSpendingGrowth5Y    9.24799     growth   SBUX
# dividendGrowthRate5Y        21.644     growth   SBUX
# ebitdaCagr5Y                8.8923     growth   SBUX
# ebitdaInterimCagr5Y        8.43955     growth   SBUX
# epsGrowth3Y                15.4784     growth   SBUX
# epsGrowth5Y                16.5851     growth   SBUX
# epsGrowthQuarterlyYoy      22.5483     growth   SBUX
# epsGrowthTTMYoy            35.0101     growth   SBUX
# focfCagr5Y                             growth   SBUX
# netMarginGrowth5Y          1.52589     growth   SBUX
# revenueGrowth3Y            7.53777     growth   SBUX
# revenueGrowth5Y             10.016     growth   SBUX
# revenueGrowthQuarterlyYoy  7.00167     growth   SBUX
# revenueGrowthTTMYoy        6.70375     growth   SBUX
# revenueShareGrowth5Y       14.8078     growth   SBUX
# tbvCagr5Y                              growth   SBUX
# totalDebtCagr5Y            40.3811     growth   SBUX

# %% [markdown]
# ## stock quote

# %%
url10 = "https://finnhub.io/api/v1/quote?symbol={}&token={}".format(company, api_key) #url
req10 = requests.get(url10) 
print(req10.json())
# Out:
# {'c': 65.38, 'h': 67.87, 'l': 65.305, 'o': 66.56, 'pc': 0, 't': 1585575815}

# %%
url10 = "https://finnhub.io/api/v1/quote?symbol=BINANCE:BTCUSDT&token={}".format(api_key) #url
req10 = requests.get(url10) 
print(req10.json())
# Out:
# {'c': 6266.27, 'h': 6330.01, 'l': 5857.76, 'o': 5880.5, 'pc': 5881.42, 't': 1585526400}

# %% [markdown]
# ## General News

# %%
url11 = "https://finnhub.io/api/v1/news?category=general&token={}".format(api_key) #url
req11 = requests.get(url11) 
news = pd.DataFrame(req11.json())
news
# Out:
#         category    datetime  \
# 0       top news  1585554441
# 1       business  1585554404
# 2       business  1585554066
# 3   company news  1585553591
# 4       business  1585553307
# 5   company news  1585553232
# 6   company news  1585552869
# 7   company news  1585552828
# 8   company news  1585552383
# 9   company news  1585551600
# 10  company news  1585550960
# 11  company news  1585550234
# 12      top news  1585550169
# 13  company news  1585549711
# 14      business  1585549591
# 15      top news  1585549530
# 16  company news  1585549172
# 17      top news  1585548923
# 18  company news  1585548583
#
#                                              headline       id  \
# 0   Lockdown could last up to 6 months, UK warns, ...  1039335
# 1   China's big banks flag asset pressure due to v...  1039332
# 2   Ted Baker names finance chief Rachel Osborne a...  1039333
# 3   Gazprom workers leave hospital after negative ...  1039317
# 4   EasyJet grounds entire fleet as coronavirus pu...  1039334
# 5   Indonesia president plans stricter rules on mo...  1039318
# 6   UPDATE 1-Serbia to invest 5 bln euros to cope ...  1039319
# 7        European shares dip as virus fears intensify  1039320
# 8   Japanese shares drop on fears of coronavirus f...  1039312
# 9   RPT-GRAPHIC-Three months that shook global mar...  1039313
# 10  Serbia to invest 5 bln euros to cope with coro...  1039295
# 11  UPDATE 2-ABB warns on profit after hit from co...  1039280
# 12  Jefferies CFO Dies From Coronavirus Complications  1039290
# 13   ASML cuts guidance for Q1 sales amid coronavirus  1039267
# 14  EasyJet grounds fleet, furloughs cabin crew fo...  1039294
# 15  EasyJet Grounds Fleet, in Talks to Strengthen ...  1039291
# 16  UPDATE 1-Britain orders 10,000 ventilators fro...  1039268
# 17  UniCredit Suspends Dividend, Buyback as ECB Ta...  1039316
# 18  Britain orders 10,000 ventilators from F1, aer...  1039269
#
#                                                 image related     source  \
# 0   https://image.cnbcfm.com/api/v1/image/10646510...               CNBC
# 1   https://s4.reutersmedia.net/resources/r/?m=02&...            Reuters
# 2   https://s3.reutersmedia.net/resources/r/?m=02&...            Reuters
# 3   https://s2.reutersmedia.net/resources/r/?m=02&...            Reuters
# 4   https://s4.reutersmedia.net/resources/r/?m=02&...            Reuters
# 5   https://s4.reutersmedia.net/resources_v2/image...            Reuters
# 6   https://s4.reutersmedia.net/resources/r/?m=02&...            Reuters
# 7   https://s4.reutersmedia.net/resources_v2/image...            Reuters
# 8   https://s4.reutersmedia.net/resources_v2/image...            Reuters
# 9   https://s4.reutersmedia.net/resources_v2/image...            Reuters
# 10  https://s4.reutersmedia.net/resources_v2/image...            Reuters
# 11  https://s3.reutersmedia.net/resources/r/?m=02&...            Reuters
# 12  https://data.bloomberglp.com/company/sites/2/2...          Bloomberg
# 13  https://s4.reutersmedia.net/resources/r/?m=02&...            Reuters
# 14  https://s4.reutersmedia.net/resources/r/?m=02&...            Reuters
# 15  https://data.bloomberglp.com/company/sites/2/2...          Bloomberg
# 16  https://s4.reutersmedia.net/resources_v2/image...            Reuters
# 17  https://data.bloomberglp.com/company/sites/2/2...          Bloomberg
# 18  https://s4.reutersmedia.net/resources_v2/image...            Reuters
#
#                                               summary  \
# 0   Restrictive measures on every day life in the ...
# 1   China's largest state banks said the impact of...
# 2   Troubled fashion retailer Ted Baker  on Monday...
# 3   Twenty Gazprom workers, who\nwere airlifted to...
# 4   British low cost airline easyJet  said it had ...
# 5   Indonesian President Joko\nWidodo said on Mond...
# 6   * State to cover minimum wages to small and mi...
# 7   European shares fell for the second\nstraight ...
# 8   Japanese stocks retreated on\nMonday as the co...
# 9   How much damage has the\ncoronavirus and the o...
# 10  Serbia plans to offer about 5\nbillion euros (...
# 11  * Sale of Power Grids to Hitachi on track for ...
# 12
# 13  Dutch semiconductor\nequipment maker ASML said...
# 14  British low cost airline easyJet  said it had ...
# 15  EasyJet Plc grounded its entire fleet after co...
# 16  Britain has ordered more than\n10,000 ventilat...
# 17
# 18  Britain has ordered more than\n10,000 ventilat...
#
#                                                   url
# 0   https://www.cnbc.com/2020/03/30/coronavirus-uk...
# 1   https://www.reuters.com/article/us-china-banks...
# 2   https://www.reuters.com/article/us-ted-baker-c...
# 3   https://www.reuters.com/article/us-health-coro...
# 4   https://www.reuters.com/article/us-health-coro...
# 5   https://www.reuters.com/article/health-coronav...
# 6   https://www.reuters.com/article/us-health-coro...
# 7   https://www.reuters.com/article/europe-stocks/...
# 8   https://www.reuters.com/article/japan-stocks-c...
# 9   https://www.reuters.com/article/global-markets...
# 10  https://www.reuters.com/article/health-coronav...
# 11  https://www.reuters.com/article/us-health-coro...
# 12  https://www.bloomberg.com/news/videos/2020-03-...
# 13  https://www.reuters.com/article/us-health-coro...
# 14  https://www.reuters.com/article/us-health-coro...
# 15  https://www.bloomberg.com/news/articles/2020-0...
# 16  https://www.reuters.com/article/us-health-coro...
# 17  https://www.bloomberg.com/news/articles/2020-0...
# 18  https://www.reuters.com/article/health-coronav...

# %% [markdown]
# ## company news

# %%
url12 = "https://finnhub.io/api/v1/news/{}?token={}".format(company,api_key) #url
req12 = requests.get(url12) 
compnews = pd.DataFrame(req12.json())
compnews
# Out:
#         category    datetime  \
# 0   company news  1584662400
# 1   company news  1584642839
# 2   company news  1584638943
# 3   company news  1584631430
# 4   company news  1584628702
# 5   company news  1584571381
# 6   company news  1584551279
# 7   company news  1584546079
# 8   company news  1584539700
# 9   company news  1584538862
# 10  company news  1584536400
# 11  company news  1584535392
# 12  company news  1584485680
# 13  company news  1584468230
# 14  company news  1584466478
# 15  company news  1584464284
# 16  company news  1584460845
# 17  company news  1584459045
# 18  company news  1584439028
# 19  company news  1584421380
#
#                                              headline       id  \
# 0   Four more big names temporarily close in Chelt...  1029110
# 1   Starbucks CEO On Coffee Chain's Buyback Progra...  1029111
# 2         Starbucks baristas push for stores to close  1029112
# 3   All the freebies NHS frontline workers can get...  1029113
# 4   Starbucks e restaurantes Ginos encerram tempor...  1029114
# 5   Starbucks Seeks to Reassure Investors | Market...  1029115
# 6   Starbucks or Luckin Coffee: Is LK Stock the Be...  1029116
# 7   Starbucks Approves Buy-Back Plan of 40 Million...  1029117
# 8   Starbucks announces share buyback program for ...  1024750
# 9   STARBUCKS CORPORATION : Stock Market News and ...  1024751
# 10  Starbucks Hosts Virtual Annual Meeting of Shar...  1024752
# 11  Dunkin' limiting coffee customers to carry-out...  1024753
# 12  Starbucks y otras marcas cierran atención en l...  1024754
# 13      Strong Support Is Brewing for Starbucks Stock  1024755
# 14  Starbucks announces 'to go' only model at all ...  1024756
# 15  4 things companies should be doing right now f...  1024757
# 16  Starbucks Expects ‘Range of Cryptocurrencies’ ...  1024758
# 17  Bakkt Cash Integrating with Starbucks' Mobile App  1024759
# 18  Bakkt Announces Integration with Starbucks to ...  1022717
# 19  Bakkt Announces New Direct Payment Integration...  1022718
#
#                                                 image related  \
# 0   https://i2-prod.gloucestershirelive.co.uk/inco...    SBUX
# 1   https://cdn2.benzinga.com/files/imagecache/og_...    SBUX
# 2   https://thenypost.files.wordpress.com/2020/03/...    SBUX
# 3   https://i2-prod.mirror.co.uk/incoming/article2...    SBUX
# 4   https://cdn4.jornaldenegocios.pt/images/2018-0...    SBUX
# 5   https://www.marketscreener.com/images/twitter_...    SBUX
# 6   https://investorplace.com/wp-content/uploads/2...    SBUX
# 7   https://www.nasdaq.com/sites/acquia.prod/files...    SBUX
# 8   https://s.wsj.net/public/resources/MWimages/MW...    SBUX
# 9   https://www.marketscreener.com/images/twitter_...    SBUX
# 10  https://mms.businesswire.com/media/20200318005...    SBUX
# 11  https://static.foxnews.com/foxnews.com/content...    SBUX
# 12  https://www.eltiempo.com/files/image_450_300/u...    SBUX
# 13  https://investorplace.com/wp-content/uploads/2...    SBUX
# 14  https://o.aolcdn.com/images/dims3/GLOB/legacy_...    SBUX
# 15  https://image.cnbcfm.com/api/v1/image/10643918...    SBUX
# 16  https://i1.wp.com/dailyhodl.com/wp-content/upl...    SBUX
# 17  https://static.cryptoglobe.com/filer_public_th...    SBUX
# 18  https://www.coinspeaker.com/wp-content/uploads...    SBUX
# 19  https://images.cointelegraph.com/images/740_aH...    SBUX
#
#                   source                                            summary  \
# 0   Gloucestershire Live  The Playfarm has also closed its doors, follow...
# 1         Benzinga Feeds  Coffee chain Starbucks Corporation (NASDAQ: SB...
# 2          New York Post  Coffee may feel essential, but in the face of ...
# 3          Mirror Online  Chains like Paul, McDonald's, Pret and Starbuc...
# 4     Jornal de Negócios  A Alsea informou hoje que, perante a declaraçã...
# 5         MarketScreener  By Heather Haddon Starbucks Corp. sought to re...
# 6          InvestorPlace  In February, Luckin Coffee came under attack f...
# 7                 Nasdaq  Starbucks Corp. ( SBUX ), said its board of di...
# 8            MarketWatch  Starbucks Corp. said Wednesday that it has aut...
# 9         MarketScreener  STARBUCKS CORPORATION : News, information and ...
# 10         Business Wire  SEATTLE--(BUSINESS WIRE)--Starbucks hosts its ...
# 11              Fox News  Dunkin’ is taking a cue from Starbucks and dit...
# 12             El Tiempo  Marcas del grupo Alsea sólo mantendrán domicil...
# 13         InvestorPlace  While Wall Street runs around in panic, smart ...
# 14                  Aol.  Filed under: Finance , Business , Companies In...
# 15                  CNBC  Regina Phelps is the founder of Emergency Mana...
# 16        The Daily Hodl  Starbucks is pilot testing a new feature that ...
# 17       cryptoglobe.com  Intercontinental Exchange's trading platform h...
# 18           Coinspeaker  Users of the Starbucks mobile app will soon ha...
# 19         Cointelegraph  A new payment option for users of the Starbuck...
#
#                                                   url
# 0   https://www.gloucestershirelive.co.uk/whats-on...
# 1   https://www.benzinga.com/news/20/03/15609618/s...
# 2   https://nypost.com/2020/03/19/starbucks-barist...
# 3   https://www.mirror.co.uk/money/shopping-deals/...
# 4   https://www.jornaldenegocios.pt/economia/coron...
# 5   https://www.marketscreener.com/STARBUCKS-CORPO...
# 6   https://investorplace.com/2020/03/starbucks-or...
# 7   https://www.nasdaq.com/articles/starbucks-appr...
# 8   https://www.marketwatch.com/story/starbucks-an...
# 9   https://www.marketscreener.com/STARBUCKS-CORPO...
# 10  https://www.businesswire.com/news/home/2020031...
# 11  https://www.foxnews.com/food-drink/dunkin-limi...
# 12  https://www.eltiempo.com/economia/starbucks-y-...
# 13  https://investorplace.com/2020/03/strong-suppo...
# 14  https://www.aol.com/article/finance/2020/03/17...
# 15  https://www.cnbc.com/2020/03/17/what-companies...
# 16  https://dailyhodl.com/2020/03/17/starbucks-exp...
# 17  https://www.cryptoglobe.com/latest/2020/03/bak...
# 18  https://www.coinspeaker.com/bakkt-starbucks-ca...
# 19  https://cointelegraph.com/news/bakkt-announces...

# %% [markdown]
# ## Major Developments

# %%
url13 = "https://finnhub.io/api/v1/major-development?symbol={}&token={}'".format(company,api_key) #url
req13 = requests.get(url13) 
# print(req13.json())

# %% [markdown]
# ## New Sentiment

# %%
url14 = "https://finnhub.io/api/v1/news-sentiment?symbol={}&token={}".format(company,api_key) #url
req14 = requests.get(url14) 
print(req14.json())
# Out:
# {'buzz': {'articlesInLastWeek': 58, 'buzz': 0.6408, 'weeklyAverage': 90.5}, 'companyNewsScore': 0.5, 'sectorAverageBullishPercent': 0.5066, 'sectorAverageNewsScore': 0.5019, 'sentiment': {'bearishPercent': 0.5, 'bullishPercent': 0.5}, 'symbol': 'XOM'}

# %% [markdown]
# ## Economic Code & Data

# %%
url15 = "https://finnhub.io/api/v1/economic/code?token={}".format(api_key) #url
req15 = requests.get(url15) 
# print(req15.json())

# %%
url16 = "https://finnhub.io/api/v1/economic?code=A-FRA-6682&token={}".format(api_key) #url
req16 = requests.get(url16) 
eco = pd.DataFrame(req16.json(), columns =['Date', 'Monthly Bankruptices in France'])
eco
# Out:
#            Date  Monthly Bankruptices in France
# 0    2019-12-31                           268.0
# 1    2019-11-30                           284.0
# 2    2019-10-31                           259.0
# 3    2019-09-30                           281.0
# 4    2019-08-31                           329.0
# ..          ...                             ...
# 355  1990-05-31                           458.0
# 356  1990-04-30                           436.0
# 357  1990-03-31                           483.0
# 358  1990-02-28                           388.0
# 359  1990-01-31                           391.0
#
# [360 rows x 2 columns]
