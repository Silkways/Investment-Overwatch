# %% [markdown]
# # I. Relevant Imports & loading

# %%
from sklearn.experimental import enable_iterative_imputer  
from sklearn.datasets import fetch_california_housing
from sklearn.impute import SimpleImputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import KNNImputer
from sklearn.model_selection import KFold
import scipy.cluster.hierarchy as shc
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import make_blobs
from yellowbrick.cluster import KElbowVisualizer
from yellowbrick.cluster import InterclusterDistance
# from yellowbrick.features import PCA
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import fcluster

from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from code_ref import movecol
from code_ref import plot_corr
from code_ref import bpsns
from code_ref import toCsv
from code_ref import Zscale

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# loading clean data and extracting an array for modelling purposes

# %%
tickers = pd.read_csv('ticker_data/tickers_final.csv')

# %%
df = pd.read_csv('clean_data/clean_data.csv')
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
complete1 = df.iloc[:,1:28]

# %%
country = pd.DataFrame(df.merge(tickers, left_on = 'symbol', right_on = 'Ticker'))

# %%
counts = pd.DataFrame(country.Country.value_counts()).reset_index()
counts.rename(columns = {'index':'country', 'Country':'n_companies'}, inplace = True)

# %%
f, ax = plt.subplots(figsize=(20, 10))
plt.title('Companies per country')
bpsns('country', 'n_companies', counts)
plt.savefig('visualizations/companies_country.png')

# %% [markdown]
# # II. Scaling data for modelling

# %% [markdown]
# We use StandardScaler as our method computing the z-score for each observation.

# %%
complete1_scaled = Zscale(complete1)

# %% [markdown]
# # III. Principal Component Analysis (PCA)

# %% [markdown]
# We test PCA here prior to clustering to see if we can simplify the dimensionality in the dataset

# %%
pca_alt = PCA(n_components = None)
pca_complete1_scaled = pca_alt.fit_transform(complete1_scaled)

# %%
plt.figure()
plt.plot(np.cumsum(pca_alt.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Companies Dataset Explained Variance')
plt.savefig('visualizations/pca_components.png')
plt.show()

# %%
pca_alt = PCA(n_components = 23)
alt30 = pca_alt.fit_transform(complete1_scaled)
print('23 principal components explain:', pca_alt.explained_variance_ratio_.sum(), 'of the data variance')
# Out:
# 23 principal components explain: 0.9685154238160052 of the data variance

# %%
alt_df = pd.DataFrame(alt30, columns=[f'PC{x+1}' for x in range((pca_alt.n_components_))])

alt_df.head()
# Out:
#         PC1       PC2        PC3       PC4       PC5        PC6       PC7  \
# 0 -0.932541  0.892955  12.357426  1.594627 -2.945677  -6.206292  3.904740
# 1 -1.692079  1.997133  21.765696  2.802785 -5.710407 -13.250377  8.409888
# 2 -0.517314  0.154118   5.846607  0.666466  0.301552  -3.655640  0.595716
# 3 -0.671888  0.645743   7.754040  0.981164 -1.100683  -6.235803  1.628267
# 4 -0.318961  0.817836   1.042650  0.135558 -0.194997  -0.845893  0.139335
#
#         PC8       PC9      PC10  ...      PC14      PC15      PC16      PC17  \
# 0  2.650315 -0.153223  0.238962  ...  0.740151  0.681528 -0.506271 -0.041019
# 1  5.144093 -0.684553  0.523440  ...  1.380697  1.185203 -1.229506  0.404547
# 2  1.299204  0.135248  0.336328  ...  0.554560  0.183737 -0.462615  0.261151
# 3  2.126052  1.542326  0.179462  ...  1.162896  0.356287 -0.760677 -0.464901
# 4  0.084252  0.086921 -0.062059  ... -0.006126 -0.142188 -0.126108  0.109835
#
#        PC18      PC19      PC20      PC21      PC22      PC23
# 0 -0.820117 -0.873715  0.446909 -0.039284 -0.924957 -4.642433
# 1  0.266516  0.189188  0.200804 -0.657242  0.222703 -1.336106
# 2  0.527135 -1.205436  0.051174  0.952773  0.996381 -2.710502
# 3  0.172708 -0.786753 -0.089766  1.084008  2.294773  0.998571
# 4  0.395936 -0.153207  0.119984 -0.062178  0.441623  0.082149
#
# [5 rows x 23 columns]

# %% [markdown]
# Evaluating effect of PCA:
#
# - We could reduce the dataset to 23 principal components as opposed to 27 and preserve most of the variance of the data.
# - We will run clustering on PCA data but considering the limited effect of PCA on this data we will focus on non-PCA data.

# %%
complete1
# Out:
#       metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 0                        410825.3000                  1.934379e+06
# 1                        133155.3000                  4.429320e+05
# 2                         16052.5800                  3.881314e+05
# 3                         58268.4800                  7.050311e+05
# 4                       -155641.0000                  3.219231e+06
# ...                              ...                           ...
# 8642                    -849453.9355                  1.168019e+06
# 8643                    -810546.1370                  3.049924e+06
# 8644                      71174.8035                  1.842825e+05
# 8645                      29784.9700                  4.655280e+05
# 8646                    -202016.6525                  2.489800e+05
#
#       metric.receivablesTurnoverAnnual  \
# 0                            11.284440
# 1                             6.690699
# 2                            15.074940
# 3                             6.973920
# 4                           170.816300
# ...                                ...
# 8642                         12.043480
# 8643                        202.307575
# 8644                          9.350430
# 8645                          5.106880
# 8646                         22.760760
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 0                                   19.40911
# 1                                   29.93606
# 2                                    6.57306
# 3                                    5.05381
# 4                                    3.70202
# ...                                      ...
# 8642                                 4.81754
# 8643                                -3.03933
# 8644                               -39.89987
# 8645                                 0.05188
# 8646                                 4.94381
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 0                                    18.63398             38.718250
# 1                                    61.20183             52.764357
# 2                                     7.71885             38.289440
# 3                                     7.91697             53.188140
# 4                                     6.06133             47.072970
# ...                                       ...                   ...
# 8642                                 47.59596             84.209640
# 8643                                 -0.16750             82.212780
# 8644                               -169.99190             24.898900
# 8645                                  1.38347             62.201700
# 8646                                 25.43451             44.708457
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 0                    37.817770                       21.23809
# 1                    54.018287                       30.06225
# 2                    40.990010                        4.13586
# 3                    53.562780                        8.26467
# 4                    50.629230                       -4.83473
# ...                        ...                            ...
# 8642                 84.556760                       39.95187
# 8643                 65.077754                      106.46740
# 8644                 19.561240                      -76.23400
# 8645                 64.207170                        6.95282
# 8646                 44.374438                       49.75335
#
#       metric.netProfitMargin5Y  metric.dividendGrowthRate5Y  ...  \
# 0                     21.89832                    11.229900  ...
# 1                     25.11008                    38.208420  ...
# 2                      2.87305                    19.595689  ...
# 3                      8.60255                     2.041380  ...
# 4                     25.37806                    12.018900  ...
# ...                        ...                          ...  ...
# 8642                  47.65050                    -1.389070  ...
# 8643                 106.24440                    11.081378  ...
# 8644                 -10.26382                     0.707898  ...
# 8645                   8.72242                    -0.471700  ...
# 8646                  40.47186                    19.055060  ...
#
#       metric.freeCashFlowAnnual  metric.longTermDebt/equityAnnual  \
# 0                  44777.000000                        101.457600
# 1                  55843.000000                         81.795250
# 2                  21653.000000                         65.273930
# 3                  14345.000000                         82.134500
# 4                   1522.000000                        434.619100
# ...                         ...                               ...
# 8642                   0.555304                          0.595290
# 8643                  -0.782424                          1.946025
# 8644                  -1.356202                          0.475960
# 8645                  84.762600                         90.966390
# 8646                   7.935083                          8.390382
#
#       metric.netInterestCoverageAnnual  metric.payoutRatioAnnual  \
# 0                            23.609307                 25.570070
# 1                            22.797158                 23.640280
# 2                            18.933590                 38.788651
# 3                             3.773710                108.115100
# 4                            23.397624                188.957059
# ...                                ...                       ...
# 8642                          8.423310                106.726900
# 8643                       -754.042359                 63.378094
# 8644                         -0.369370                 42.401914
# 8645                         33.200000                130.026800
# 8646                         51.533630                 26.649310
#
#       metric.quickRatioAnnual  metric.totalDebt/totalEquityAnnual  \
# 0                    1.501290                          119.404800
# 1                    0.765348                          161.458000
# 2                    0.863630                           67.379950
# 3                    0.753100                           88.560480
# 4                    0.309640                          450.691100
# ...                       ...                                 ...
# 8642                 4.053382                           17.737900
# 8643                 2.305304                            4.867440
# 8644                 0.166510                           30.890050
# 8645                 0.713080                           98.704480
# 8646                 0.830620                           13.717441
#
#       metric.dividendYield5Y  metric.dividendYieldIndicatedAnnual  \
# 0                   1.486500                             1.275840
# 1                   1.589900                             3.594610
# 2                   2.882723                             5.395433
# 3                   5.342350                             7.574650
# 4                   4.390640                             8.981560
# ...                      ...                                  ...
# 8642                3.204510                             3.577780
# 8643                7.627042                            15.961122
# 8644                4.194674                            14.894328
# 8645                3.974600                             4.820940
# 8646                1.846710                             2.563280
#
#       metric.capitalSpendingGrowth5Y  metric.inventoryTurnoverAnnual
# 0                           1.352890                       40.134460
# 1                          13.139539                        7.554975
# 2                          28.074190                        8.788510
# 3                          -1.722560                       29.863710
# 4                           8.579920                        5.362020
# ...                              ...                             ...
# 8642                      -47.469440                      141.611651
# 8643                       -6.547941                       32.584788
# 8644                       35.637490                        0.169430
# 8645                        2.784790                       15.404580
# 8646                      -14.319302                       38.998049
#
# [8647 rows x 27 columns]

# %% [markdown]
# # IV. KMeans Clustering - PCA Data

# %% [markdown]
# - We use the 'Elbow' method to look for the optimal number of clusters.
# - We don't treat the elbow method as absolute truth but use it as an indicator of where our model potentially fits best.
# - We use two variants of the elbow method: Distortion (sum of squared distances from centroid) / clainski_harabasz (ratio of dispersion between / within clusters)
# - The elbow method works well for closely clustered data.

# %%
km = KMeans()
visualizer = KElbowVisualizer(km, k=(4,80))

# %%
visualizer.fit(alt_df)
visualizer.poof().get_figure()

# %%
visualizer1 = KElbowVisualizer(km, k=(4,80), metric ='calinski_harabasz', locate_elbow = True)
visualizer1.fit(alt_df)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# KElbowVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x1a1a0e19b0>,
#                  k=None, locate_elbow=True, metric='calinski_harabasz',
#                  model=None, timings=True)

# %% [markdown]
# Limited results with this second method

# %%
visualizer1.poof().get_figure()

# %%
number_clusters = 33
pca_km_alt = KMeans(n_clusters = number_clusters, n_init = 10, random_state =0)
pca_km_alt.fit(alt_df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=33, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
predicted_alt_pca = pca_km_alt.predict(alt_df)

# %%
predicted_alt_pca
# Out:
# array([14, 14, 27, ...,  8, 16, 16], dtype=int32)

# %% [markdown]
# No cluster separation visible within the elected principal components below

# %%
plt.axis([-5,5,-2,5])
plt.ylabel('PC1')
plt.xlabel('PC2')
plt.scatter(alt30[:,0], alt30[:,1], c = predicted_alt_pca, cmap = 'viridis')

# %% [markdown]
# From the below we notice clusters that deal with bunched data combined with outliers
#  - multidimensional scaling used

# %%
model = KMeans(33)
int_clust_dist = InterclusterDistance(model)
int_clust_dist.fit(alt_df)
int_clust_dist.poof().get_figure()

# %% [markdown]
# Adding another dimension to understand data dispersion

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('revenueEmployeeAnnual') #check PCA extraction
ax.set_ylabel('receivablesTurnoverAnnual') #check PCA extraction
ax.set_zlabel('freeOperatingCashFlow/revenue5Y') #check PCA extraction
ax.scatter(alt30[:,1], alt30[:,2], alt30[:,3], c=predicted_alt_pca , s=60,cmap="RdYlGn")
ax.set_xlim3d(-5, 10)
ax.set_ylim3d(-5,10)
ax.set_zlim3d(-10,7)
ax.view_init(30, 15)
plt.show()

# %% [markdown]
# # V. KMeans Clustering - without PCA data

# %%
km = KMeans()
elbow = KElbowVisualizer(km, k=(4,80))

# %%
elbow.fit(complete1_scaled)
elbow.poof().get_figure()

# %%
model = KMeans(100)
int_clust_dist_1 = InterclusterDistance(model)
int_clust_dist_1.fit(alt_df)
int_clust_dist_1.poof().get_figure()

# %% [markdown]
# From the displays above we understand some of the limitations of using the elbow method to find the 'optimal' number of clusters.
#
#    - We consider our data and devide to increase the number of clusters to simplify the inspection of clusters

# %%
alt_km = KMeans(n_clusters = 100, n_init = 10, random_state =0)
alt_km.fit(complete1_scaled)
pred_alt = alt_km.predict(complete1_scaled)
alt_df_2 = pd.DataFrame(pred_alt, columns = ['company cluster'])
alt_df_2.reset_index(inplace = True)
alt_df_2['companies'] = 1

# %%
clusters = pd.pivot_table(alt_df_2,  values = 'companies', index = 'company cluster', aggfunc = np.sum)
clusters = clusters.reset_index().sort_values(by = 'companies', ascending = False)

# %%
f, ax = plt.subplots(figsize=(35, 10))
plt.axis([0,100,0,500])
sns.set(style = "darkgrid")
sns.barplot(x='company cluster', y = 'companies', data = clusters).set_title('KMeans Clusters')
# Out:
# Text(0.5, 1.0, 'KMeans Clusters')

# %% [markdown]
# Plotting some of our clusters shows the difficulty in displaying multidimensional data.

# %%
plt.figure(figsize = [15,10])
plt.axis([-0.1,0.1,0,0.5])
plt.scatter(complete1_scaled[:, 4], 
            complete1_scaled[:, 5], c=pred_alt, s=50, cmap='viridis');

# %% [markdown]
# Adding another dimension to our plots highlights a slightly more pronounced separation of the clusters

# %%
fig = plt.figure(figsize=(17,10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('FOCF / Revenue 5Y Avg - Scaled')
ax.set_ylabel('FOCF / Revenue TTM - Scaled')
ax.set_zlabel('Gross Margin 5Y Avg - Scaled')
ax.scatter(complete1_scaled[:,3], complete1_scaled[:,4], complete1_scaled[:,5], c=pred_alt, s=60)
ax.set_xlim3d(-6, 6)
ax.set_ylim3d(-6,6)
ax.set_zlim3d(-6,6)
ax.view_init(30, 15)
plt.savefig('visualizations/3D_cluster_KMeans.png')
plt.show()

# %% [markdown]
# ## Inspecting cluster consituents

# %%
findata_w_clusters = pd.merge(df, alt_df_2, left_index = True, right_index = True)

# %%
findata_w_clusters.drop(columns = ['index', 'companies'], inplace = True)

# %% [markdown]
# We have tagged back each of the companies to its assigned cluster

# %%
findata_w_clusters.iloc[:,1:29]
# Out:
#       metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 0                        410825.3000                  1.934379e+06
# 1                        133155.3000                  4.429320e+05
# 2                         16052.5800                  3.881314e+05
# 3                         58268.4800                  7.050311e+05
# 4                       -155641.0000                  3.219231e+06
# ...                              ...                           ...
# 8642                    -849453.9355                  1.168019e+06
# 8643                    -810546.1370                  3.049924e+06
# 8644                      71174.8035                  1.842825e+05
# 8645                      29784.9700                  4.655280e+05
# 8646                    -202016.6525                  2.489800e+05
#
#       metric.receivablesTurnoverAnnual  \
# 0                            11.284440
# 1                             6.690699
# 2                            15.074940
# 3                             6.973920
# 4                           170.816300
# ...                                ...
# 8642                         12.043480
# 8643                        202.307575
# 8644                          9.350430
# 8645                          5.106880
# 8646                         22.760760
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 0                                   19.40911
# 1                                   29.93606
# 2                                    6.57306
# 3                                    5.05381
# 4                                    3.70202
# ...                                      ...
# 8642                                 4.81754
# 8643                                -3.03933
# 8644                               -39.89987
# 8645                                 0.05188
# 8646                                 4.94381
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 0                                    18.63398             38.718250
# 1                                    61.20183             52.764357
# 2                                     7.71885             38.289440
# 3                                     7.91697             53.188140
# 4                                     6.06133             47.072970
# ...                                       ...                   ...
# 8642                                 47.59596             84.209640
# 8643                                 -0.16750             82.212780
# 8644                               -169.99190             24.898900
# 8645                                  1.38347             62.201700
# 8646                                 25.43451             44.708457
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 0                    37.817770                       21.23809
# 1                    54.018287                       30.06225
# 2                    40.990010                        4.13586
# 3                    53.562780                        8.26467
# 4                    50.629230                       -4.83473
# ...                        ...                            ...
# 8642                 84.556760                       39.95187
# 8643                 65.077754                      106.46740
# 8644                 19.561240                      -76.23400
# 8645                 64.207170                        6.95282
# 8646                 44.374438                       49.75335
#
#       metric.netProfitMargin5Y  metric.dividendGrowthRate5Y  ...  \
# 0                     21.89832                    11.229900  ...
# 1                     25.11008                    38.208420  ...
# 2                      2.87305                    19.595689  ...
# 3                      8.60255                     2.041380  ...
# 4                     25.37806                    12.018900  ...
# ...                        ...                          ...  ...
# 8642                  47.65050                    -1.389070  ...
# 8643                 106.24440                    11.081378  ...
# 8644                 -10.26382                     0.707898  ...
# 8645                   8.72242                    -0.471700  ...
# 8646                  40.47186                    19.055060  ...
#
#       metric.longTermDebt/equityAnnual  metric.netInterestCoverageAnnual  \
# 0                           101.457600                         23.609307
# 1                            81.795250                         22.797158
# 2                            65.273930                         18.933590
# 3                            82.134500                          3.773710
# 4                           434.619100                         23.397624
# ...                                ...                               ...
# 8642                          0.595290                          8.423310
# 8643                          1.946025                       -754.042359
# 8644                          0.475960                         -0.369370
# 8645                         90.966390                         33.200000
# 8646                          8.390382                         51.533630
#
#       metric.payoutRatioAnnual  metric.quickRatioAnnual  \
# 0                    25.570070                 1.501290
# 1                    23.640280                 0.765348
# 2                    38.788651                 0.863630
# 3                   108.115100                 0.753100
# 4                   188.957059                 0.309640
# ...                        ...                      ...
# 8642                106.726900                 4.053382
# 8643                 63.378094                 2.305304
# 8644                 42.401914                 0.166510
# 8645                130.026800                 0.713080
# 8646                 26.649310                 0.830620
#
#       metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# 0                             119.404800                1.486500
# 1                             161.458000                1.589900
# 2                              67.379950                2.882723
# 3                              88.560480                5.342350
# 4                             450.691100                4.390640
# ...                                  ...                     ...
# 8642                           17.737900                3.204510
# 8643                            4.867440                7.627042
# 8644                           30.890050                4.194674
# 8645                           98.704480                3.974600
# 8646                           13.717441                1.846710
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 0                                1.275840                        1.352890
# 1                                3.594610                       13.139539
# 2                                5.395433                       28.074190
# 3                                7.574650                       -1.722560
# 4                                8.981560                        8.579920
# ...                                   ...                             ...
# 8642                             3.577780                      -47.469440
# 8643                            15.961122                       -6.547941
# 8644                            14.894328                       35.637490
# 8645                             4.820940                        2.784790
# 8646                             2.563280                      -14.319302
#
#       metric.inventoryTurnoverAnnual  company cluster
# 0                          40.134460               71
# 1                           7.554975               56
# 2                           8.788510               71
# 3                          29.863710                5
# 4                           5.362020               92
# ...                              ...              ...
# 8642                      141.611651                1
# 8643                       32.584788               65
# 8644                        0.169430               88
# 8645                       15.404580               59
# 8646                       38.998049               89
#
# [8647 rows x 28 columns]

# %% [markdown]
# Let's compare now two clusters and see what differentiates them
#
#    - We select smaller clusters to simplify our observation process.

# %%
cl26 = findata_w_clusters.loc[findata_w_clusters['company cluster'] == 26].describe()
cl62 = findata_w_clusters.loc[findata_w_clusters['company cluster'] == 62].describe()
cl26
# Out:
#        metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# count                    3.100000e+01                  3.100000e+01
# mean                     1.338549e+05                  1.047564e+06
# std                      3.003500e+05                  2.014354e+06
# min                     -1.087631e+05                  6.515391e+04
# 25%                      1.212704e+03                  2.434229e+05
# 50%                      2.208383e+04                  4.727553e+05
# 75%                      8.732774e+04                  8.319947e+05
# max                      1.194957e+06                  1.095713e+07
#
#        metric.receivablesTurnoverAnnual  \
# count                         31.000000
# mean                         151.128279
# std                          726.356158
# min                            1.365780
# 25%                            4.469430
# 50%                            8.862530
# 75%                           19.744960
# max                         4061.032000
#
#        metric.freeOperatingCashFlow/revenue5Y  \
# count                               31.000000
# mean                                 4.454382
# std                                  9.648756
# min                                -26.718850
# 25%                                  1.960110
# 50%                                  3.926970
# 75%                                  6.500105
# max                                 35.127250
#
#        metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# count                                31.000000             31.000000
# mean                                 18.853270             36.226178
# std                                  65.126169             18.522993
# min                                 -19.482540              7.111250
# 25%                                   3.553765             25.559775
# 50%                                   5.939730             31.867190
# 75%                                  12.791275             46.964186
# max                                 365.943195             86.370710
#
#        metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# count                 31.000000                      31.000000
# mean                  37.468427                       1.276471
# std                   18.791591                      16.886950
# min                    7.564810                     -51.173666
# 25%                   24.150525                       1.416850
# 50%                   33.630070                       4.317420
# 75%                   49.543075                       9.892470
# max                   87.700410                      25.681470
#
#        metric.netProfitMargin5Y  metric.dividendGrowthRate5Y  ...  \
# count                 31.000000                    31.000000  ...
# mean                   3.826057                    -0.119523  ...
# std                   16.761955                    14.425688  ...
# min                  -56.643010                   -29.269790  ...
# 25%                    1.334905                    -5.932170  ...
# 50%                    5.318230                     0.000000  ...
# 75%                    8.996535                     7.177260  ...
# max                   55.985140                    32.950250  ...
#
#        metric.longTermDebt/equityAnnual  metric.netInterestCoverageAnnual  \
# count                         31.000000                         31.000000
# mean                          75.175572                         14.888533
# std                           76.274768                         26.730919
# min                            0.000000                        -37.051720
# 25%                           10.247435                          1.829960
# 50%                           43.790350                          8.019320
# 75%                          125.774250                         22.177150
# max                          250.580400                        123.150600
#
#        metric.payoutRatioAnnual  metric.quickRatioAnnual  \
# count                 31.000000                31.000000
# mean                  43.986358                 1.286684
# std                   71.560858                 0.969060
# min                    0.000000                 0.278650
# 25%                    1.828345                 0.805838
# 50%                   32.339370                 1.051210
# 75%                   48.403616                 1.517200
# max                  371.441400                 5.640560
#
#        metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# count                           31.000000               31.000000
# mean                           130.940727                3.244927
# std                            204.162871                3.612845
# min                              0.000000                0.000000
# 25%                             31.050875                2.050889
# 50%                             60.560700                2.632524
# 75%                            158.303500                3.150126
# max                           1117.063000               21.181610
#
#        metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# count                            31.000000                       31.000000
# mean                              6.137440                       22.828563
# std                               5.705837                       21.895257
# min                               0.811760                      -24.035920
# 25%                               3.782655                        8.597634
# 50%                               5.020862                       18.576884
# 75%                               6.279883                       33.971780
# max                              32.762990                       68.980210
#
#        metric.inventoryTurnoverAnnual  company cluster
# count                       31.000000             31.0
# mean                        22.729737             26.0
# std                         25.724393              0.0
# min                          1.797690             26.0
# 25%                          7.740347             26.0
# 50%                         11.076950             26.0
# 75%                         28.302013             26.0
# max                         99.958025             26.0
#
# [8 rows x 28 columns]

# %%
cl26_mean = cl26[1:2].T.round(1).reset_index()
cl62_mean = cl62[1:2].T.round(1).reset_index()

# %%
cl2662 = pd.merge(cl26_mean, cl62_mean, on = 'index').rename(columns = {'index': 'metric', 'mean_x':'cl26_average', 'mean_y':'cl62_average'})

# %% [markdown]
# Some Observations at the cluster level:
#
#    - Outliers in the data are skewing some of the metrics (e.g. Average Net Profit Margin over 5 year-period)
#    - Overall cl52 seems to contain more high gross margin businesses with high amounts of debt (some of the metrics in CL51 indicates some potentially distressed companies)
#    - Both clusters seem to suffer from high depreciation & amortization + interest / tax expenses which suggest a high amount of asset and asset servicing costs

# %%
cl2662
# Out:
#                                      metric  cl26_average  cl62_average
# 0            metric.netIncomeEmployeeAnnual      133854.9     -574770.5
# 1              metric.revenueEmployeeAnnual     1047563.7      450980.7
# 2          metric.receivablesTurnoverAnnual         151.1           7.5
# 3    metric.freeOperatingCashFlow/revenue5Y           4.5      -37977.0
# 4   metric.freeOperatingCashFlow/revenueTTM          18.9      -11395.6
# 5                      metric.grossMargin5Y          36.2        -199.5
# 6                  metric.grossMarginAnnual          37.5        -593.5
# 7             metric.netProfitMargin%Annual           1.3       -4475.2
# 8                  metric.netProfitMargin5Y           3.8      -39618.2
# 9               metric.dividendGrowthRate5Y          -0.1           2.6
# 10                        metric.focfCagr5Y         120.3           8.8
# 11                   metric.revenueGrowth5Y          17.2           2.0
# 12                   metric.totalDebtCagr5Y          65.2           6.4
# 13                     metric.netDebtAnnual        1051.1        -140.4
# 14                metric.peNormalizedAnnual          23.8          41.0
# 15                   metric.pfcfShareAnnual          16.5         134.4
# 16      metric.currentEv/freeCashFlowAnnual          39.1          30.3
# 17                metric.freeCashFlowAnnual         167.6         -15.7
# 18         metric.longTermDebt/equityAnnual          75.2           6.6
# 19         metric.netInterestCoverageAnnual          14.9        -343.3
# 20                 metric.payoutRatioAnnual          44.0          57.5
# 21                  metric.quickRatioAnnual           1.3          28.9
# 22       metric.totalDebt/totalEquityAnnual         130.9           7.2
# 23                   metric.dividendYield5Y           3.2           4.2
# 24      metric.dividendYieldIndicatedAnnual           6.1          10.8
# 25           metric.capitalSpendingGrowth5Y          22.8          -2.3
# 26           metric.inventoryTurnoverAnnual          22.7          32.9
# 27                          company cluster          26.0          62.0

# %%
cl26_comp = findata_w_clusters.loc[findata_w_clusters['company cluster'] == 26]

# %% [markdown]
# Peek into Cluster 52:
#
#  - Main metric contributing to cl52 seems to be Gross Margin
#  - Sectors include: Industrials, Financial Servicem Real Estate and Entertainment
#  - cl52 could serve as a basic screen if you're scouting for high gross margin businesses

# %%
cl26_comp = cl26_comp.merge(tickers, left_on = 'symbol', right_on = 'Ticker')
cl26_comp.to_csv('cl26.csv')

# %%
movecol(cl26_comp, cols_to_move = ['Name', 'Category Name'], ref_col = 'symbol', place = 'After')
# Out:
#       symbol                                 Name  \
# 0         AI     Arlington Asset Investment Corp.
# 1        ABG        Asbury Automotive Group, Inc.
# 2       BLDR           Builders FirstSource, Inc.
# 3        SAL              Salisbury Bancorp, Inc.
# 4       DISH             DISH Network Corporation
# 5        VMC             Vulcan Materials Company
# 6         DK              Delek US Holdings, Inc.
# 7       PETS                 PetMed Express, Inc.
# 8       ETSY                           Etsy, Inc.
# 9        GES                         Guess', Inc.
# 10      GLOB                         Globant S.A.
# 11      NVEE                     NV5 Global, Inc.
# 12      HDSN             Hudson Technologies Inc.
# 13      UPLD                Upland Software, Inc.
# 14      KGJI                Kingold Jewelry, Inc.
# 15       SUM               Summit Materials, Inc.
# 16       CMT      Core Molding Technologies, Inc.
# 17    CTD.AX  Corporate Travel Management Limited
# 18    BGA.AX                  Bega Cheese Limited
# 19    EKI.PA                         EKINOPS S.A.
# 20  ALFPC.PA                   Fountaine Pajot SA
# 21    ERGO.L                          Ergomed plc
# 22     BEZ.L                          Beazley plc
# 23     BOO.L                       boohoo.com plc
# 24    CINE.L                  Cineworld Group plc
# 25    MACF.L                 MacFarlane Group plc
# 26     PHD.L                PROACTIS Holdings PLC
# 27     RWA.L                   Robert Walters PLC
# 28    DAT.OL                     Data Respons ASA
# 29    ASC.OL       ABG Sundal Collier Holding ASA
# 30    FIC.MI                 First Capital S.p.A.
#
#                           Category Name  metric.netIncomeEmployeeAnnual  \
# 0                   Mortgage Investment                    1.194957e+06
# 1                      Auto Dealerships                    2.208383e+04
# 2            General Building Materials                    1.440318e+04
# 3            Regional - Northeast Banks                    6.455652e+04
# 4                          CATV Systems                    9.328556e+04
# 5            General Building Materials                    7.263745e+04
# 6        Oil & Gas Refining & Marketing                    8.790334e+04
# 7                         Drug Delivery                    1.955440e+05
# 8               Specialty Retail, Other                    8.675213e+04
# 9                        Apparel Stores                    6.269234e+05
# 10      Information Technology Services                    5.337714e+03
# 11                   Technical Services                    8.268709e+03
# 12                Diversified Machinery                   -1.087631e+05
# 13                 Application Software                   -6.053502e+04
# 14                                 Gold                    7.889603e+04
# 15           General Building Materials                    1.018717e+04
# 16                    Rubber & Plastics                   -7.590626e+03
# 17            Recreational Goods, Other                    3.651959e+04
# 18             Food - Major Diversified                    5.106829e+04
# 19  Semiconductor Equipment & Materials                   -5.012019e+03
# 20            Recreational Goods, Other                    1.630322e+04
# 21                        Biotechnology                    6.724597e+05
# 22        Property & Casualty Insurance                    1.297821e+05
# 23           Textile - Apparel Clothing                    2.175521e+04
# 24            Recreational Goods, Other                    4.318958e+04
# 25               Packaging & Containers                    1.695096e+04
# 26         Business Software & Services                   -5.697745e+04
# 27      Staffing & Outsourcing Services                   -5.127955e+04
# 28      Information Technology Services                   -2.912305e+03
# 29      Investment Brokerage - National                    9.291722e+05
# 30      Investment Brokerage - National                   -3.636559e+04
#
#     metric.revenueEmployeeAnnual  metric.receivablesTurnoverAnnual  \
# 0                   1.095713e+07                          2.646900
# 1                   8.635090e+05                         48.342610
# 2                   4.727553e+05                         11.473230
# 3                   2.513739e+05                          8.862530
# 4                   8.004803e+05                         20.855800
# 5                   5.751579e+05                          9.189320
# 6                   2.469314e+06                         14.228310
# 7                   1.468492e+06                        117.260700
# 8                   7.742469e+05                         59.238440
# 9                   1.511241e+06                         10.033034
# 10                  6.515391e+04                          4.928170
# 11                  1.771451e+05                          2.890020
# 12                  6.794927e+05                         14.648740
# 13                  2.970474e+05                          4.426890
# 14                  3.942144e+06                       4061.032000
# 15                  3.703567e+05                          8.937920
# 16                  1.417552e+05                          6.875630
# 17                  1.135930e+05                          1.613580
# 18                  2.687834e+05                          7.839620
# 19                  2.200097e+05                          4.069680
# 20                  2.396002e+05                        136.378100
# 21                  3.052146e+05                          4.095340
# 22                  1.813930e+06                          7.522719
# 23                  4.874883e+05                         54.771020
# 24                  5.185460e+05                         18.634120
# 25                  2.921267e+05                          4.586720
# 26                  1.443369e+05                          2.668700
# 27                  1.320368e+06                          5.850690
# 28                  2.472456e+05                          4.511970
# 29                  4.796712e+05                          1.365780
# 30                  2.067640e+05                         25.198360
#
#     metric.freeOperatingCashFlow/revenue5Y  \
# 0                                35.127250
# 1                                 1.566970
# 2                                 2.932350
# 3                                16.810080
# 4                                -6.562680
# 5                                 5.290470
# 6                                 1.082500
# 7                                 5.230100
# 8                                16.029980
# 9                                 7.567767
# 10                                3.926970
# 11                                6.411260
# 12                               12.474490
# 13                                4.147590
# 14                                2.686400
# 15                                3.725990
# 16                                1.800350
# 17                               11.869340
# 18                               -0.263320
# 19                               -6.294900
# 20                               12.610610
# 21                                2.119870
# 22                                6.277810
# 23                                4.063730
# 24                                6.588950
# 25                                2.460370
# 26                                3.942790
# 27                                2.574980
# 28                                2.940230
# 29                               -4.333610
# 30                              -26.718850
#
#     metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 0                                  1.622930              7.111250
# 1                                  3.856980             16.184600
# 2                                  5.372980             25.414710
# 3                                 21.032240             44.003607
# 4                                 16.155650             28.595460
# 5                                  8.846540             25.704840
# 6                                  0.510850             14.594600
# 7                                  3.900820             33.452160
# 8                                 23.177400             66.728660
# 9                                365.943195             52.913092
# 10                                 0.158219             38.363500
# 11                                 7.324060             48.113590
# 12                                20.245710             14.882900
# 13                                 4.956950             66.579150
# 14                                -8.015410              9.049340
# 15                                 7.186270             31.867190
# 16                                 3.250550             12.615770
# 17                                11.414590             30.797416
# 18                                11.848430             15.963920
# 19                                 2.332950             53.169080
# 20                                -3.627231             44.752120
# 21                                15.809830             36.240300
# 22                                13.734120             45.814782
# 23                                 5.939730             54.879220
# 24                                 7.275100             29.788510
# 25                                 5.838790             31.178630
# 26                                 4.185450             86.370710
# 27                                 4.086830             30.509280
# 28                                 7.438190             51.654810
# 29                                32.131200             31.612110
# 30                               -19.482540             44.106204
#
#     metric.grossMarginAnnual  ...  metric.totalDebt/totalEquityAnnual  \
# 0                  22.821750  ...                          1117.06300
# 1                  16.211530  ...                           280.25680
# 2                  27.152640  ...                           185.24950
# 3                  47.547204  ...                            17.90770
# 4                  29.848280  ...                           122.26700
# 5                  25.479300  ...                            49.52705
# 6                  17.893790  ...                           124.05330
# 7                  33.630070  ...                             0.00000
# 8                  66.881360  ...                           208.29840
# 9                  54.562162  ...                            45.27383
# 10                 38.548670  ...                            25.69989
# 11                 48.214520  ...                           100.62450
# 12                 10.591820  ...                           219.43650
# 13                 68.955290  ...                           246.67460
# 14                 10.676830  ...                           312.75950
# 15                 31.312520  ...                           131.35750
# 16                  7.564810  ...                            58.57319
# 17                 30.143337  ...                             6.91045
# 18                 20.442800  ...                            38.61286
# 19                 55.909380  ...                            26.03456
# 20                 50.871630  ...                           105.88620
# 21                 43.256900  ...                            14.75828
# 22                 47.654550  ...                            36.06719
# 23                 54.730200  ...                             2.84318
# 24                 37.087210  ...                           266.08570
# 25                 32.003780  ...                            60.56070
# 26                 87.700410  ...                            72.29624
# 27                 33.344300  ...                            63.57410
# 28                 55.238720  ...                            53.99659
# 29                 34.819359  ...                            15.48111
# 30                 20.426108  ...                            51.03312
#
#     metric.dividendYield5Y  metric.dividendYieldIndicatedAnnual  \
# 0                21.181610                            12.841985
# 1                 3.134152                             5.472880
# 2                 2.988207                             5.637595
# 3                 2.835800                             3.372090
# 4                 3.271532                             5.901499
# 5                 0.771210                             1.370830
# 6                 2.606080                             7.994840
# 7                 3.417300                             3.817600
# 8                 2.150228                             4.772994
# 9                 4.853100                             7.563030
# 10                2.209974                             4.361088
# 11                2.985247                             7.792933
# 12                1.724660                             5.539609
# 13                2.819027                             4.952374
# 14                3.072788                             5.325890
# 15                3.200700                             5.690386
# 16                3.199261                             8.072452
# 17                1.504200                             4.608290
# 18                1.742770                             2.272730
# 19                0.000000                             6.658267
# 20                1.387530                             2.722010
# 21                2.632524                             4.411872
# 22                2.376990                             3.747710
# 23                2.767356                             5.020862
# 24                3.166100                            32.762990
# 25                2.364240                             0.811760
# 26                0.997230                             5.313573
# 27                1.951550                             1.437700
# 28                2.352757                             4.443153
# 29                8.364790                            13.622290
# 30                2.563840                             1.947370
#
#     metric.capitalSpendingGrowth5Y  metric.inventoryTurnoverAnnual  \
# 0                         6.873897                       20.435723
# 1                        -1.970050                        5.886580
# 2                        34.423450                        9.158740
# 3                        -0.954990                       14.265681
# 4                       -24.035920                       29.284080
# 5                        11.303330                        8.276350
# 6                        10.321370                        9.323890
# 7                        68.980210                        8.415010
# 8                        12.461310                       99.958025
# 9                        -2.851870                       82.789760
# 10                       18.189930                       64.500492
# 11                       26.047740                       18.101885
# 12                        6.847140                        1.797690
# 13                        3.849890                       29.576602
# 14                       13.191840                       16.875500
# 15                       18.437590                        7.291890
# 16                       -6.923160                       11.076950
# 17                       66.832300                       15.308746
# 18                       17.428490                        4.476570
# 19                       51.550480                        3.719350
# 20                       30.859950                        3.314940
# 21                       46.818670                        8.188803
# 22                       26.685710                        9.826629
# 23                       58.827610                        6.743370
# 24                       41.908470                       80.500730
# 25                       33.520110                        9.358290
# 26                       45.634970                       28.445486
# 27                       23.475020                        6.731612
# 28                       27.987250                       28.158540
# 29                       23.387820                       50.053757
# 30                       18.576884                       12.780167
#
#     company cluster  Unnamed: 0    Ticker  Exchange         Country
# 0                26         173        AI       NYQ             USA
# 1                26         320       ABG       NYQ             USA
# 2                26        2382      BLDR       NMS             USA
# 3                26        2569       SAL       NCM             USA
# 4                26        3883      DISH       NMS             USA
# 5                26        3964       VMC       NYQ             USA
# 6                26        5412        DK       NYQ             USA
# 7                26        7125      PETS       NMS             USA
# 8                26        7212      ETSY       NMS             USA
# 9                26        9462       GES       NYQ             USA
# 10               26        9603      GLOB       NYQ             USA
# 11               26        9649      NVEE       NCM             USA
# 12               26       10600      HDSN       NCM             USA
# 13               26       12061      UPLD       NGM             USA
# 14               26       12113      KGJI       NCM             USA
# 15               26       16061       SUM       NYQ             USA
# 16               26       16081       CMT       ASE             USA
# 17               26       41045    CTD.AX       ASX       Australia
# 18               26       45077    BGA.AX       ASX       Australia
# 19               26        8104    EKI.PA       PAR          France
# 20               26       34920  ALFPC.PA       PAR          France
# 21               26        8043    ERGO.L       LSE  United Kingdom
# 22               26       12206     BEZ.L       LSE  United Kingdom
# 23               26       50262     BOO.L       LSE  United Kingdom
# 24               26       55658    CINE.L       LSE  United Kingdom
# 25               26       70915    MACF.L       LSE  United Kingdom
# 26               26       92952     PHD.L       LSE  United Kingdom
# 27               26       95199     RWA.L       LSE  United Kingdom
# 28               26        6154    DAT.OL       OSL          Norway
# 29               26       28169    ASC.OL       OSL          Norway
# 30               26       68115    FIC.MI       MIL           Italy
#
# [31 rows x 35 columns]

# %% [markdown]
# ## KMeans Preliminary Conclusions:
#
#    - KMeans clusters can give us some high level information on specific company groups and provide some ground to do a deeper dive
#    - KMeans is sensitive to outliers and we see it in our results where even a large number of smaller clusters are still influenced by outliers. This limits the conclusions we are able to draw.
#    - To remediate the issues above we should run multiple iterations of KMeans and focus on a smaller and more consistent set of data

# %% [markdown]
# # VI. Agglomerative Clustering (AGNES)

# %% [markdown]
#  - We decide to use an alternative method of clustering -> Agglomerative Clustering
#  - Fewer hidden assumptions in hierarchical clustering
#  - We have more flexibility in choosing the optimal number of clusters
#  - This method is more computationally intensive but provides more intuitive results

# %%
clustering_alt = AgglomerativeClustering().fit_predict(complete1_scaled)

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize=(30,20))

for link, cluster, ax in zip([shc.complete(complete1_scaled),
                                 shc.average(complete1_scaled),
                                 shc.single(complete1_scaled),
                                 shc.ward(complete1_scaled)],
                                ['c1','c2','c3','c4'],
                                [ax1,ax2,ax3, ax4]):
    shc.dendrogram(link, ax=ax, color_threshold=100, truncate_mode='level',
                  )

ax1.set_title('Complete Linkage')
ax2.set_title('Average Linkage')
ax3.set_title('Single Linkage')
ax4.set_title('Ward Linkage');
plt.savefig('visualizations/dendrogram.png')

# %% [markdown]
# Use Cophenetic Correlation to identify best linkage distance metric
#
#    - Choose the linkage with the highest resulting value as it measures how well the dendogram preserves pairwise distance between observations

# %%
methods = ['complete', 'single', 'ward', 'average']

# %%
for m in methods: 
    Z = linkage(complete1_scaled, m)
    c, coph_dists = cophenet(Z, pdist(complete1_scaled))
    print(m,':',c)
# Out:
# complete : 0.8631965550391456
# single : 0.9279570788988177
# ward : 0.418046119115535
# average : 0.9825049372987652

# %%
main_link = linkage(complete1_scaled, 'average')

# %% [markdown]
# Each main_link[i] gives us an array for the clusters that are merged at each iteration of the model
#
#    - The first / second number of each array corresponds to the index or a merged cluster of indices
#
#    - The Third number of each array is the distance between the merged clusters
#
#    - The Fourth number of each array is the number of samples (companies) in the cluster created

# %%
main_link[0:10]
# Out:
# array([[7.091e+03, 7.092e+03, 0.000e+00, 2.000e+00],
#        [7.093e+03, 8.647e+03, 0.000e+00, 3.000e+00],
#        [7.094e+03, 8.648e+03, 0.000e+00, 4.000e+00],
#        [7.095e+03, 8.649e+03, 0.000e+00, 5.000e+00],
#        [7.096e+03, 8.650e+03, 0.000e+00, 6.000e+00],
#        [7.097e+03, 8.651e+03, 0.000e+00, 7.000e+00],
#        [7.098e+03, 8.652e+03, 0.000e+00, 8.000e+00],
#        [7.099e+03, 8.653e+03, 0.000e+00, 9.000e+00],
#        [7.100e+03, 8.654e+03, 0.000e+00, 1.000e+01],
#        [7.101e+03, 8.655e+03, 0.000e+00, 1.100e+01]])

# %%
idx = [[7091,7093,7094]]
plt.figure(figsize = (15,10))
plt.scatter(main_link[:,0], main_link[:,1])
plt.scatter(main_link[idx,0],main_link[idx,1], c = 'r')
plt.show()

# %% [markdown]
# Dendogram Truncation - Showing the remaining 100 clusters in the hierarchy
#
# -  Risk here is random selection / intuition based selection

# %%
plt.figure(figsize = (15,15))
plt.xlabel('sample index or cluster combination')
plt.ylabel('distance')
dendrogram(
    main_link,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=100,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.savefig('visualizations/dendogram_avg_dist.png')
plt.show()

# %% [markdown]
# Retrieving Clusters - Our data has companies very close together complemented by outliers. We set the limit distance to a very low value to allow us to dive into the components of the cluster where we hope to extract insights.

# %%
clust_dist = [0.1, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 10]

print('Dendogram Truncation based on Euclidian Distance')

for values in clust_dist: 
    clusters = fcluster(main_link, values, criterion = 'distance')
    clh = pd.DataFrame(clusters, columns = ['cluster_ID'])
    clh['comp_per_clust'] = 1
    piv = pd.pivot_table(clh, 'comp_per_clust', 'cluster_ID', aggfunc = np.sum)
    piv1 = piv.reset_index().sort_values('comp_per_clust', ascending = False)
    print('----------------------------------------------')
    print('#Unique Clusters: ', piv1.cluster_ID.value_counts().sum())
    print('Company per cluster metrics:')
    print('cluster distance of', values,'yields -->', 'median:',piv1.comp_per_clust.median(),'; mean:',piv1.comp_per_clust.mean(),'; min:',piv1.comp_per_clust.min(),'; max:',piv1.comp_per_clust.max())
    print('----------------------------------------------')
# Out:
# Dendogram Truncation based on Euclidian Distance
# ----------------------------------------------
# #Unique Clusters:  8491
# Company per cluster metrics:
# cluster distance of 0.1 yields --> median: 1.0 ; mean: 1.0183723942998468 ; min: 1 ; max: 32
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  6633
# Company per cluster metrics:
# cluster distance of 0.5 yields --> median: 1.0 ; mean: 1.3036333484094678 ; min: 1 ; max: 36
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  2766
# Company per cluster metrics:
# cluster distance of 1 yields --> median: 1.0 ; mean: 3.126174981923355 ; min: 1 ; max: 452
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  1328
# Company per cluster metrics:
# cluster distance of 1.5 yields --> median: 1.0 ; mean: 6.511295180722891 ; min: 1 ; max: 2577
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  761
# Company per cluster metrics:
# cluster distance of 2 yields --> median: 1.0 ; mean: 11.362680683311432 ; min: 1 ; max: 4537
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  482
# Company per cluster metrics:
# cluster distance of 2.5 yields --> median: 1.0 ; mean: 17.939834024896264 ; min: 1 ; max: 5413
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  333
# Company per cluster metrics:
# cluster distance of 3 yields --> median: 1.0 ; mean: 25.966966966966968 ; min: 1 ; max: 6642
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  246
# Company per cluster metrics:
# cluster distance of 3.5 yields --> median: 1.0 ; mean: 35.15040650406504 ; min: 1 ; max: 7046
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  197
# Company per cluster metrics:
# cluster distance of 4 yields --> median: 1.0 ; mean: 43.89340101522843 ; min: 1 ; max: 7626
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  163
# Company per cluster metrics:
# cluster distance of 4.5 yields --> median: 1.0 ; mean: 53.04907975460123 ; min: 1 ; max: 7705
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  144
# Company per cluster metrics:
# cluster distance of 5 yields --> median: 1.0 ; mean: 60.048611111111114 ; min: 1 ; max: 7823
# ----------------------------------------------
# ----------------------------------------------
# #Unique Clusters:  67
# Company per cluster metrics:
# cluster distance of 10 yields --> median: 1.0 ; mean: 129.0597014925373 ; min: 1 ; max: 8432
# ----------------------------------------------

# %% [markdown]
# Elect a distance of 2 for our truncation / returns each cluster 'id' for companies

# %%
clusters_f = fcluster(main_link, 2, 'distance')
clusters_f
# Out:
# array([ 17,  15, 128, ..., 693, 693, 693], dtype=int32)

# %%
cls_id = pd.DataFrame(clusters_f, columns = ['comp_clust_id'])

# %%
agglo_results = pd.merge(df, cls_id, left_index = True, right_index = True).merge(tickers, left_on ='symbol', right_on = 'Ticker')
agglo_results['count'] = 1

# %%
movecol(agglo_results.drop(columns =['Unnamed: 0']), cols_to_move = ['Name', 'Category Name'], ref_col = 'symbol', place = 'After').head()
# Out:
#   symbol                         Name                Category Name  \
# 0   AAPL                   Apple Inc.         Electronic Equipment
# 1    BAC  Bank of America Corporation           Money Center Banks
# 2   AMZN             Amazon.com, Inc.  Catalog & Mail Order Houses
# 3      T                    AT&T Inc.  Telecom Services - Domestic
# 4     MO           Altria Group, Inc.                   Cigarettes
#
#    metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 0                       410825.30                     1934379.0
# 1                       133155.30                      442932.0
# 2                        16052.58                      388131.4
# 3                        58268.48                      705031.1
# 4                      -155641.00                     3219231.0
#
#    metric.receivablesTurnoverAnnual  metric.freeOperatingCashFlow/revenue5Y  \
# 0                         11.284440                                19.40911
# 1                          6.690699                                29.93606
# 2                         15.074940                                 6.57306
# 3                          6.973920                                 5.05381
# 4                        170.816300                                 3.70202
#
#    metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 0                                 18.63398             38.718250
# 1                                 61.20183             52.764357
# 2                                  7.71885             38.289440
# 3                                  7.91697             53.188140
# 4                                  6.06133             47.072970
#
#    metric.grossMarginAnnual  ...  metric.totalDebt/totalEquityAnnual  \
# 0                 37.817770  ...                           119.40480
# 1                 54.018287  ...                           161.45800
# 2                 40.990010  ...                            67.37995
# 3                 53.562780  ...                            88.56048
# 4                 50.629230  ...                           450.69110
#
#    metric.dividendYield5Y  metric.dividendYieldIndicatedAnnual  \
# 0                1.486500                             1.275840
# 1                1.589900                             3.594610
# 2                2.882723                             5.395433
# 3                5.342350                             7.574650
# 4                4.390640                             8.981560
#
#    metric.capitalSpendingGrowth5Y  metric.inventoryTurnoverAnnual  \
# 0                        1.352890                       40.134460
# 1                       13.139539                        7.554975
# 2                       28.074190                        8.788510
# 3                       -1.722560                       29.863710
# 4                        8.579920                        5.362020
#
#    comp_clust_id  Ticker  Exchange  Country  count
# 0             17    AAPL       NMS      USA      1
# 1             15     BAC       NYQ      USA      1
# 2            128    AMZN       NMS      USA      1
# 3             46       T       NYQ      USA      1
# 4            651      MO       NYQ      USA      1
#
# [5 rows x 35 columns]

# %% [markdown]
# We can notice are more evenly split cluster base vs KMeans clustering with the added customization of AGNES

# %%
clust_count = agglo_results.pivot_table('count', index = ['comp_clust_id'], aggfunc = np.sum).reset_index()
clust_count = clust_count.query('5 <= count <=50')
f, ax = plt.subplots(figsize=(35, 10))
sns.set(style = "darkgrid")
sns.barplot(x='comp_clust_id', y = 'count', data = clust_count, palette = 'GnBu_d').set_title('Agglomerative Clustering Results')
plt.savefig('visualizations/agg_clust_display.png')

# %% [markdown]
# ## Cluster Deep Dive

# %%
cl484 = agglo_results.loc[agglo_results['comp_clust_id'] == 484].describe()
cl621 = agglo_results.loc[agglo_results['comp_clust_id'] == 621].describe()

# %%
cl484_mean = cl484[1:2].T.round(1).reset_index()
cl621_mean = cl621[1:2].T.round(1).reset_index()

# %%
cl_combined = pd.merge(cl484_mean, cl621_mean, on = 'index').rename(columns = {'index': 'metric', 'mean_x':'cl484_average', 'mean_y':'cl621_average'})

# %% [markdown]
# Some initial observations:
#
#    - Large disparity in profitability / financial profile across the two clusters
#    - Clusters appear to display for a fairer representation as outliers should not be as prominent with this clustering method
#    - cl621 seems to be a cluser composed of financially strong cluster:
#       - High average gross margin ~45%
#       - FOCF growth ~ 26.9%
#       - P/E ratio is lower than the other cluster at 24
#       - strong metrics are also companied by large growth in debt 42% CAGR

# %%
cl_combined[0:27]
# Out:
#                                      metric  cl484_average  cl621_average
# 0            metric.netIncomeEmployeeAnnual        -6752.2       -17360.9
# 1              metric.revenueEmployeeAnnual       955821.7       453079.5
# 2          metric.receivablesTurnoverAnnual            5.7           24.1
# 3    metric.freeOperatingCashFlow/revenue5Y         -358.9         -410.1
# 4   metric.freeOperatingCashFlow/revenueTTM         -151.9         -476.6
# 5                      metric.grossMargin5Y           59.5           39.8
# 6                  metric.grossMarginAnnual           93.9           36.2
# 7             metric.netProfitMargin%Annual         -177.6          -21.3
# 8                  metric.netProfitMargin5Y         -368.6          -12.4
# 9               metric.dividendGrowthRate5Y           30.1            1.2
# 10                        metric.focfCagr5Y           15.1          -17.3
# 11                   metric.revenueGrowth5Y           83.8            9.1
# 12                   metric.totalDebtCagr5Y            6.5           49.5
# 13                     metric.netDebtAnnual         -803.7          102.1
# 14                metric.peNormalizedAnnual           40.6           38.1
# 15                   metric.pfcfShareAnnual           32.3           96.7
# 16      metric.currentEv/freeCashFlowAnnual           21.6           57.8
# 17                metric.freeCashFlowAnnual           72.0           -3.6
# 18         metric.longTermDebt/equityAnnual            0.0           43.4
# 19         metric.netInterestCoverageAnnual         -442.4           21.2
# 20                 metric.payoutRatioAnnual           20.2           81.5
# 21                  metric.quickRatioAnnual            7.6            1.7
# 22       metric.totalDebt/totalEquityAnnual            0.0           57.4
# 23                   metric.dividendYield5Y            2.8            3.3
# 24      metric.dividendYieldIndicatedAnnual            5.7            6.4
# 25           metric.capitalSpendingGrowth5Y           78.3           18.3
# 26           metric.inventoryTurnoverAnnual            1.9            7.3

# %% [markdown]
# Ploting a correlation matrix could provide us some additional details of the relationships of metrics in cluster

# %%
plt.figure(figsize = [25,25])
corr = cl621.iloc[:,3:25].corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cl621_corr = sns.heatmap(corr, mask = mask, annot=True, linewidths = .5, cmap = 'YlGnBu');

# %% [markdown]
# A few points from the heatmap:
#
#    - high gross margin within the cluster is correlated with debt growth
#    - Higher P/E ratios have higher debt and higher gross margin - opportunity to study companies with lower P/E and debt

# %%
cl621_comp = agglo_results.loc[agglo_results['comp_clust_id'] == 621]
movecol(cl621_comp, cols_to_move = ['Name', 'Category Name'], ref_col = 'symbol', place = 'After')
# Out:
#        symbol                                  Name  \
# 117      AEIS      Advanced Energy Industries, Inc.
# 388      AGFS             AgroFresh Solutions, Inc.
# 507       BHE           Benchmark Electronics, Inc.
# 903       DDD                3D Systems Corporation
# 940      CSII          Cardiovascular Systems, Inc.
# 1539     FNHC    Federated National Holding Company
# 1556     ZIXI                       Zix Corporation
# 2366       HY  Hyster-Yale Materials Handling, Inc.
# 3363   NXT.AX                        NEXTDC Limited
# 3580   APE.AX                   A.P. Eagers Limited
# 4472  TTR1.DE                        Technotrans AG
# 4578  STAL.PA                          Installux SA
# 5139    PG.TO            Premier Gold Mines Limited
# 5220   SBB.TO            Sabina Gold & Silver Corp.
# 5231   USA.TO           Americas Silver Corporation
# 5474    JUP.L           Jupiter Fund Management Plc
# 5794    VTU.L                      Vertu Motors plc
# 5820   SMWH.L                          WH Smith PLC
# 6142   LDSG.L                       Leeds Group plc
# 8535   DEA.MI                    DeA Capital S.p.A.
#
#                        Category Name  metric.netIncomeEmployeeAnnual  \
# 117          Diversified Electronics                     8575.440000
# 388                    Conglomerates                  -209906.400000
# 507           Printed Circuit Boards                     2220.379000
# 903             Computer Peripherals                   -27349.570000
# 940   Medical Appliances & Equipment                     -368.763500
# 1539   Property & Casualty Insurance                     2995.556000
# 1556            Application Software                   -35251.500000
# 2366         Trucks & Other Vehicles                     4662.420000
# 3363            Data Storage Devices                   210335.047850
# 3580                Auto Dealerships                   135277.117335
# 4472              Business Equipment                     4160.574000
# 4578      General Building Materials                    18502.810000
# 5139                            Gold                  -122178.491700
# 5220                            Gold                  -330040.800000
# 5231    Industrial Metals & Minerals                   -79239.530000
# 5474                Asset Management                   231261.800000
# 5794                Auto Dealerships                     3764.965000
# 5820         Specialty Retail, Other                     7673.452000
# 6142              Textile Industrial                     8898.828150
# 8535                Asset Management                  -181211.560700
#
#       metric.revenueEmployeeAnnual  metric.receivablesTurnoverAnnual  \
# 117                   1.197553e+05                          4.547170
# 388                   5.894801e+05                          2.490410
# 507                   2.149853e+05                          4.147460
# 903                   2.470911e+05                          5.330720
# 940                   3.586652e+05                          7.377070
# 1539                  1.229514e+06                          7.741933
# 1556                  4.173959e+05                         10.240800
# 2366                  4.193376e+05                          7.050330
# 3363                  1.132282e+06                          5.704650
# 3580                  5.382332e+05                         24.941970
# 4472                  1.543931e+05                          8.130090
# 4578                  3.094180e+05                          5.982270
# 5139                  3.868346e+05                        224.014300
# 5220                  4.320187e+05                         12.397459
# 5231                  9.622951e+04                         10.932060
# 5474                  9.799625e+05                          4.360890
# 5794                  6.785174e+05                         76.507860
# 5820                  1.231807e+05                         45.803280
# 6142                  2.580999e+05                          7.762080
# 8535                  3.761962e+05                          5.944790
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 117                                17.408190
# 388                                 9.430130
# 507                                 3.827160
# 903                                -0.660340
# 940                                -3.965260
# 1539                                9.872770
# 1556                               13.367230
# 2366                                0.220010
# 3363                             -124.376900
# 3580                                0.379890
# 4472                                0.071350
# 4578                                2.305210
# 5139                              -16.453570
# 5220                            -8126.598076
# 5231                              -17.984390
# 5474                                7.178480
# 5794                                0.348080
# 5820                                3.597010
# 6142                               -1.170300
# 8535                               22.171340
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 117                                   2.94113             48.991780
# 388                                   9.33937             65.762180
# 507                                   1.53129              8.894340
# 903                                   1.20745             46.255570
# 940                                   0.43992             80.426610
# 1539                                  6.98066             31.785716
# 1556                                  1.32505             70.590400
# 2366                                  0.18227             16.568500
# 3363                               -183.88430             71.907400
# 3580                                  0.34432             16.782380
# 4472                                  3.57722             32.286290
# 4578                                 -2.62754             32.761260
# 5139                                -30.71541             18.923020
# 5220                              -9304.71900             13.241812
# 5231                                  0.58038             15.599950
# 5474                                  4.53136             87.735980
# 5794                                  1.05825             10.964560
# 5820                                  2.14746             59.334710
# 6142                                  0.95812             21.598720
# 8535                                -46.74328             46.437531
#
#       metric.grossMarginAnnual  ...  metric.dividendYield5Y  \
# 117                  40.009230  ...                1.629620
# 388                  73.510720  ...                4.094890
# 507                   8.835870  ...                3.745400
# 903                  44.197050  ...                3.631547
# 940                  80.775510  ...                3.316831
# 1539                 31.309569  ...                1.371210
# 1556                 55.654220  ...                2.521723
# 2366                 16.535030  ...                1.860840
# 3363                 76.225040  ...                2.080178
# 3580                 17.015170  ...                3.571430
# 4472                 29.488710  ...                2.490360
# 4578                 30.646920  ...                2.317680
# 5139                  0.025600  ...                3.251340
# 5220                -12.380482  ...                9.547914
# 5231                  2.886490  ...                4.315838
# 5474                 90.412590  ...                3.852680
# 5794                 10.800920  ...                2.705640
# 5820                 60.486760  ...                2.740870
# 6142                 21.848270  ...                3.004438
# 8535                 46.398867  ...                3.457442
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 117                              3.945642                        47.52230
# 388                              6.514298                        26.28839
# 507                              3.437160                        -5.00170
# 903                              5.076181                         0.42650
# 940                              6.350031                       -23.33028
# 1539                             3.214290                        16.05431
# 1556                             5.171718                        27.92066
# 2366                             3.383960                         0.49002
# 3363                             3.872025                        28.28640
# 3580                             7.193730                        52.78424
# 4472                             3.893810                        45.49636
# 4578                             2.954550                        20.65126
# 5139                            13.836025                        27.58077
# 5220                            12.529020                         8.54397
# 5231                            11.510451                        -0.97215
# 5474                             9.334060                         6.72492
# 5794                             3.243240                        18.42308
# 5820                             5.762380                        13.01612
# 6142                             6.053947                        20.33203
# 8535                            11.111110                        34.83305
#
#       metric.inventoryTurnoverAnnual  comp_clust_id  Unnamed: 0   Ticker  \
# 117                         2.885900            621         186     AEIS
# 388                         1.899680            621         742     AGFS
# 507                         6.617340            621        2173      BHE
# 903                         2.874340            621        3909      DDD
# 940                         2.751060            621        3951     CSII
# 1539                       15.285329            621        4904     FNHC
# 1556                       10.184986            621        4929     ZIXI
# 2366                        5.025150            621       10616       HY
# 3363                        4.483175            621       16664   NXT.AX
# 3580                        4.484500            621       37773   APE.AX
# 4472                        5.184940            621       93248  TTR1.DE
# 4578                        4.037310            621        8829  STAL.PA
# 5139                        4.697460            621        3602    PG.TO
# 5220                       19.265506            621        9774   SBB.TO
# 5231                        7.417330            621       10187   USA.TO
# 5474                       26.961616            621        8861    JUP.L
# 5794                        4.519890            621       21840    VTU.L
# 5820                        3.365850            621       23116   SMWH.L
# 6142                        3.017070            621       70926   LDSG.L
# 8535                       11.079225            621       79390   DEA.MI
#
#       Exchange         Country  count
# 117        NMS             USA      1
# 388        NMS             USA      1
# 507        NYQ             USA      1
# 903        NYQ             USA      1
# 940        NMS             USA      1
# 1539       NGM             USA      1
# 1556       NMS             USA      1
# 2366       NYQ             USA      1
# 3363       ASX       Australia      1
# 3580       ASX       Australia      1
# 4472       GER         Germany      1
# 4578       PAR          France      1
# 5139       TOR          Canada      1
# 5220       TOR          Canada      1
# 5231       TOR          Canada      1
# 5474       LSE  United Kingdom      1
# 5794       LSE  United Kingdom      1
# 5820       LSE  United Kingdom      1
# 6142       LSE  United Kingdom      1
# 8535       MIL           Italy      1
#
# [20 rows x 36 columns]

# %%
cl621_comp.to_csv('cl621.csv')

# %%
cl484_comp = agglo_results.loc[agglo_results['comp_clust_id'] == 484]
movecol(cl484_comp, cols_to_move = ['Name', 'Category Name'], ref_col = 'symbol', place = 'After').head(n=3)
# Out:
#      symbol                            Name  Category Name  \
# 1829   EXEL                  Exelixis, Inc.  Biotechnology
# 2520   RARE  Ultragenyx Pharmaceutical Inc.  Biotechnology
#
#       metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 1829                        583128.1                     1757993.0
# 2520                       -596632.6                      153650.4
#
#       metric.receivablesTurnoverAnnual  \
# 1829                           6.84075
# 2520                           4.55046
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 1829                                44.25941
# 2520                              -761.98640
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 1829                                 53.12412             96.605350
# 2520                               -356.95760             22.371678
#
#       metric.grossMarginAnnual  ...  metric.dividendYield5Y  \
# 1829                  96.58009  ...                2.599944
# 2520                  91.31458  ...                2.918959
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 1829                             4.338041                        93.42684
# 2520                             7.131437                        63.13797
#
#       metric.inventoryTurnoverAnnual  comp_clust_id  Unnamed: 0  Ticker  \
# 1829                         2.91296            484        7011    EXEL
# 2520                         0.96803            484       11693    RARE
#
#       Exchange  Country  count
# 1829       NMS      USA      1
# 2520       NMS      USA      1
#
# [2 rows x 36 columns]
