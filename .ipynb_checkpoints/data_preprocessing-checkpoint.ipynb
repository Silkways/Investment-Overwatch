# %% [markdown]
# # I.Relevant imports

# %%
from sklearn.impute import KNNImputer
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from forex_python.converter import CurrencyRates
from code_ref import usd_conv

# %% [markdown]
# # II.Data Cleaning

# %% [markdown]
# Loading main dataset resulting from API pull

# %%
findata = pd.read_csv('metric_final_set.csv')

# %%
findata.drop(columns = ['Unnamed: 0'] , inplace = True)
findata.dropna(thresh = findata.shape[0]*0.3, how = 'all', axis =1, inplace = True)

# %% [markdown]
# Some primary feature selection - we are looking to simplify the dimensionality of the dataset and focus on key investment features
#
#  - This list is not exhaustive and may have some selection bias. We believe these metrics can lead us to extract information from company clusters.

# %%
findata1 = findata[['symbol','metric.netIncomeEmployeeAnnual', 'metric.revenueEmployeeAnnual','metric.receivablesTurnoverAnnual','metric.freeOperatingCashFlow/revenue5Y',
"metric.freeOperatingCashFlow/revenueTTM", 'metric.grossMargin5Y', 'metric.grossMarginAnnual',
'metric.netProfitMargin%Annual',
'metric.netProfitMargin5Y',
'metric.dividendGrowthRate5Y',
'metric.focfCagr5Y',
'metric.revenueGrowth5Y',
'metric.totalDebtCagr5Y',
'metric.netDebtAnnual',
'metric.peNormalizedAnnual',
'metric.pfcfShareAnnual',
'metric.currentEv/freeCashFlowAnnual',
'metric.freeCashFlowAnnual',
'metric.longTermDebt/equityAnnual',
'metric.netInterestCoverageAnnual',
'metric.payoutRatioAnnual',
'metric.quickRatioAnnual',
'metric.totalDebt/totalEquityAnnual',
'metric.dividendYield5Y',
'metric.dividendYieldIndicatedAnnual',
'metric.capitalSpendingGrowth5Y',
'metric.inventoryTurnoverAnnual',
]]

findata1.shape
# Out:
# (8831, 28)

# %% [markdown]
# Preliminary data observation

# %%
findata1.sample(n=10)
# Out:
#          symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 4407    1161.HK                      141354.800                     1005900.0
# 4634       SSYS                       -4774.843                      284726.9
# 5559  PCOM-B.ST                             NaN                           NaN
# 846        CBSH                       92436.480                      295128.4
# 2592         LE                        3819.802                      287168.5
# 3229       GRIF                      114625.000                     1376406.0
# 2360       PACD                     -749447.800                      309464.0
# 3997        TDY                       35538.870                      279470.0
# 3359    INGA.AS                       87909.910                      339729.7
# 4233       JASN                      -15679.060                      121984.5
#
#       metric.receivablesTurnoverAnnual  \
# 4407                          14.08468
# 4634                           4.69945
# 5559                           4.91310
# 846                                NaN
# 2592                          33.92204
# 3229                               NaN
# 2360                           6.58377
# 3997                           5.17478
# 3359                               NaN
# 4233                           9.75200
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 4407                                 6.29908
# 4634                                -1.61534
# 5559                                 0.10191
# 846                                 25.41428
# 2592                                -0.19689
# 3229                               -62.96577
# 2360                                -2.27131
# 3997                                11.15025
# 3359                                22.06104
# 4233                                -1.37495
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 4407                                  1.15697              91.75522
# 4634                                 -5.73733              41.46251
# 5559                                  0.00000               7.50195
# 846                                  25.76670                   NaN
# 2592                                 -0.79913              43.37690
# 3229                                -69.34499              70.98269
# 2360                                -44.51838              47.43591
# 3997                                 12.44468              38.34889
# 3359                                 53.14771                   NaN
# 4233                                -12.91133              21.18963
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 4407                  92.58332                       14.05257
# 4634                  49.31644                       -1.67699
# 5559                   6.34475                       -2.13363
# 846                        NaN                       31.32077
# 2592                  42.88316                        1.33016
# 3229                  72.76876                        8.32785
# 2360                   0.71112                     -242.17610
# 3997                  39.30016                       12.71653
# 3359                       NaN                       25.87643
# 4233                  22.07951                      -12.85333
#
#       metric.netProfitMargin5Y  ...  metric.freeCashFlowAnnual  \
# 4407                  10.28278  ...                      8.839
# 4634                 -45.34563  ...                    -36.494
# 5559                  -2.08140  ...                      0.000
# 846                   28.11797  ...                    347.753
# 2592                  -1.46737  ...                    -11.589
# 3229                   4.78447  ...                    -30.543
# 2360                -118.96000  ...                   -102.293
# 3997                  10.31928  ...                    393.700
# 3359                  25.49394  ...                  10021.000
# 4233                  -9.87035  ...                    -43.627
#
#       metric.longTermDebt/equityAnnual  metric.netInterestCoverageAnnual  \
# 4407                           3.57246                       18931.57000
# 4634                           0.00000                               NaN
# 5559                          85.33333                          -0.34483
# 846                            0.07714                               NaN
# 2592                         108.69020                           1.73822
# 3229                         157.08670                           2.04639
# 2360                         100.45870                          -0.73754
# 3997                          27.62736                          23.41429
# 3359                         157.73770                               NaN
# 4233                               NaN                          -0.03671
#
#       metric.payoutRatioAnnual  metric.quickRatioAnnual  \
# 4407                  94.79339                  0.73297
# 4634                       NaN                  3.06760
# 5559                       NaN                  0.52809
# 846                   27.79585                      NaN
# 2592                   0.00000                  0.59848
# 3229                  69.19302                      NaN
# 2360                       NaN                  4.59650
# 3997                   0.00000                  1.20584
# 3359                  56.24346                      NaN
# 4233                       NaN                  2.25703
#
#       metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# 4407                             4.84011                 8.99123
# 4634                             0.00000                     NaN
# 5559                           299.33330                 0.00000
# 846                             59.11888                 1.59719
# 2592                           110.16840                     NaN
# 3229                           163.55960                 0.97836
# 2360                           100.45870                     NaN
# 3997                            31.33311                     NaN
# 3359                           254.09250                 5.47001
# 4233                                 NaN                     NaN
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 4407                             22.05882                        27.36427
# 4634                                  NaN                       -16.83167
# 5559                                  NaN                             NaN
# 846                               2.20994                        -0.50113
# 2592                                  NaN                        18.54338
# 3229                              1.54943                        20.46524
# 2360                                  NaN                       -50.11215
# 3997                                  NaN                        15.23717
# 3359                              5.19481                        -2.79222
# 4233                                  NaN                        -2.94799
#
#       metric.inventoryTurnoverAnnual
# 4407                         1.48944
# 4634                         2.20793
# 5559                         7.59909
# 846                              NaN
# 2592                         2.37482
# 3229                             NaN
# 2360                         5.40867
# 3997                         5.06876
# 3359                             NaN
# 4233                         5.29665
#
# [10 rows x 28 columns]

# %% [markdown]
# # III. KNN Imputation

# %% [markdown]
#    - We elected KNNImputer to fill in missing values with the rationale that similar companies in terms of ratios would be grouped within the matrix dimensions and provide accurate inputs that would not affect the clustering outcomes. 20 nearest neighbors should preserve the accuracy of the data and avoid adding too much variance to the data.

# %%
imputer = KNNImputer(n_neighbors = 20)
complete1 = imputer.fit_transform(Xalt)

# %%
df = pd.DataFrame(complete1, index = [findata1.index, findata1.iloc[:,0]], columns = Xalt.columns).reset_index()
df.drop(columns = ['level_0'], inplace = True)

# %%
df
# Out:
#        symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 0        AAPL                   410825.300000                   1934379.000
# 1         BAC                   133155.300000                    442932.000
# 2        AMZN                    16052.580000                    388131.400
# 3           T                    58268.480000                    705031.100
# 4       GOOGL                   315551.100000                   1487178.000
# ...       ...                             ...                           ...
# 8826  TEXF.BR                  -251954.217000                    263252.880
# 8827    TRB.L                  -284442.197845                    322311.800
# 8828   ZO1.DE                   -17904.200000                   2260676.000
# 8829   TRY.AX                  -937872.754450                    378203.079
# 8830   N1H.AX                   -65287.382650                    374592.534
#
#       metric.receivablesTurnoverAnnual  \
# 0                            11.284440
# 1                             7.973046
# 2                            15.074940
# 3                             6.973920
# 4                             7.012260
# ...                                ...
# 8826                         22.760760
# 8827                          5.642860
# 8828                         40.701720
# 8829                        114.245900
# 8830                          5.237940
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 0                                   19.40911
# 1                                   29.93606
# 2                                    6.57306
# 3                                    5.05381
# 4                                   20.90443
# ...                                      ...
# 8826                                 4.94381
# 8827                                 1.82452
# 8828                                 1.02939
# 8829                               -19.62623
# 8830                               -24.90443
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 0                                    18.63398             38.718250
# 1                                    61.20183             53.779052
# 2                                     7.71885             38.289440
# 3                                     7.91697             53.188140
# 4                                    19.13541             58.188350
# ...                                       ...                   ...
# 8826                                 25.43451             47.208966
# 8827                                  4.26416             44.941730
# 8828                                  1.63264             27.269160
# 8829                                 -0.35878             -5.924430
# 8830                                 71.45435             69.161460
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 0                    37.817770                       21.23809
# 1                    55.803548                       30.06225
# 2                    40.990010                        4.13586
# 3                    53.562780                        8.26467
# 4                    55.580540                       21.21811
# ...                        ...                            ...
# 8826                 48.544562                       49.75335
# 8827                 50.098450                       -3.78852
# 8828                 29.119890                       -0.79198
# 8829                 -0.399530                      -44.23042
# 8830                 77.679180                      -62.82364
#
#       metric.netProfitMargin5Y  ...  metric.freeCashFlowAnnual  \
# 0                     21.89832  ...                44777.00000
# 1                     25.11008  ...                55843.00000
# 2                      2.87305  ...                21653.00000
# 3                      8.60255  ...                14345.00000
# 4                     21.46707  ...                30972.00000
# ...                        ...  ...                        ...
# 8826                  40.47186  ...                    7.30200
# 8827                  -9.72124  ...                    3.33500
# 8828                   0.12667  ...                   24.87641
# 8829                 -59.94664  ...                    9.81200
# 8830                 -32.71561  ...                    0.30232
#
#       metric.longTermDebt/equityAnnual  metric.netInterestCoverageAnnual  \
# 0                           101.457600                         21.364915
# 1                            81.795250                         23.594304
# 2                            65.273930                         18.933590
# 3                            82.134500                          3.773710
# 4                             2.260700                         22.797158
# ...                                ...                               ...
# 8826                          7.820562                         51.533630
# 8827                         10.492030                         67.748030
# 8828                         61.339690                         -6.080280
# 8829                          0.128460                         -4.777970
# 8830                       1752.175000                         -2.568920
#
#       metric.payoutRatioAnnual  metric.quickRatioAnnual  \
# 0                    25.570070                 1.501290
# 1                    23.640280                 0.544362
# 2                    39.613199                 0.863630
# 3                   108.115100                 0.753100
# 4                     0.000000                 3.351960
# ...                        ...                      ...
# 8826                 26.649310                 0.830620
# 8827               1102.903429                 2.321427
# 8828                 54.426176                 0.707650
# 8829                 37.573755                 0.311520
# 8830                 45.706978                 0.770862
#
#       metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# 0                             119.404800                1.486500
# 1                             161.458000                1.589900
# 2                              67.379950                2.774091
# 3                              88.560480                5.342350
# 4                               2.260700                3.017829
# ...                                  ...                     ...
# 8826                            8.766772                1.846710
# 8827                           13.471060                1.291330
# 8828                           81.612810                2.545007
# 8829                            8.128660                3.800539
# 8830                         3366.641000                2.433144
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 0                                1.275840                        1.352890
# 1                                3.594610                       11.858569
# 2                                5.604027                       28.074190
# 3                                7.574650                       -1.722560
# 4                                5.483896                       16.413080
# ...                                   ...                             ...
# 8826                             2.563280                       -7.603030
# 8827                             2.123890                        1.130880
# 8828                             3.007997                       -7.135260
# 8829                             8.609218                      -25.616750
# 8830                            12.634136                       34.844210
#
#       metric.inventoryTurnoverAnnual
# 0                          40.134460
# 1                           9.623854
# 2                           8.788510
# 3                          29.863710
# 4                          68.277300
# ...                              ...
# 8826                       22.795993
# 8827                       41.726025
# 8828                        9.588630
# 8829                        8.136950
# 8830                       33.225780
#
# [8831 rows x 28 columns]

# %% [markdown]
# # IV. Currency Conversion

# %% [markdown]
# Net Debt / Free Cash Flow are in local CCY. We need to convert them into USD to include these features in the clusters.

# %%
tick_conv = pd.read_csv('tickers_final.csv')

# %%
conv = pd.merge(df, tick_conv, left_on = 'symbol', right_on = 'Ticker').drop(columns = ['Ticker', 'Unnamed: 0'])

# %%
conv.sample()
# Out:
#       symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 6360  BIA.MI                    -18836.03086                    218723.934
#
#       metric.receivablesTurnoverAnnual  \
# 6360                           3.30581
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 6360                                 0.64264
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 6360                                 -12.1856              61.72642
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 6360                  62.40911                      -38.44551
#
#       metric.netProfitMargin5Y  ...  metric.quickRatioAnnual  \
# 6360                  -5.14979  ...                  0.34498
#
#       metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# 6360                          214.082686                2.007944
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 6360                             4.603536                         3.37257
#
#       metric.inventoryTurnoverAnnual                      Name  Exchange  \
# 6360                         1.35773  Bialetti Industrie S.p.A       MIL
#
#              Category Name  Country
# 6360  Electronic Equipment    Italy
#
# [1 rows x 32 columns]

# %%
country_ccy = pd.DataFrame(conv.Country.unique(), columns = ['country'])

# %%
mapping = {'USA': 'USD', 'Australia': 'AUD', 'Germany': 'EUR', 'France': 'EUR', 'Canada':'CAD',
           'United Kingdom': 'GBP', 'Norway': 'NOK', 'Sweden': 'SEK', 'Denmark': 'DKK', 'Singapore': 'SGD', 'Netherlands':'EUR', 'Hong Kong':'HKD', 'Spain': 'EUR', 'Italy':'EUR', 'Belgium': 'EUR'}

# %%
country_ccy['ccy'] = country_ccy.country.map((mapping))

# %%
country_ccy['ref_ccy'] = 'USD'

# %%
def usd_conv(row):
    c = CurrencyRates()
    return c.get_rate(row['ref_ccy'],row ['ccy'])

# %%
country_ccy['rate_vs_usd'] = country_ccy.apply(usd_conv, axis =1)
country_ccy
# Out:
#            country  ccy ref_ccy  rate_vs_usd
# 0              USA  USD     USD     1.000000
# 1        Australia  AUD     USD     1.605227
# 2          Germany  EUR     USD     0.920217
# 3           France  EUR     USD     0.920217
# 4           Canada  CAD     USD     1.404712
# 5   United Kingdom  GBP     USD     0.805788
# 6           Norway  NOK     USD    10.319591
# 7           Sweden  SEK     USD    10.072237
# 8          Denmark  DKK     USD     6.870065
# 9        Singapore  SGD     USD     1.424404
# 10     Netherlands  EUR     USD     0.920217
# 11       Hong Kong  HKD     USD     7.753658
# 12           Spain  EUR     USD     0.920217
# 13           Italy  EUR     USD     0.920217
# 14         Belgium  EUR     USD     0.920217

# %%
df_w_rate = pd.merge(conv, country_ccy, left_on = 'Country', right_on = 'country')
df_w_rate[['metric.freeCashFlowAnnual','metric.netDebtAnnual']] = df_w_rate[['metric.freeCashFlowAnnual','metric.netDebtAnnual']].divide(df_w_rate['rate_vs_usd'], axis = 0)

# %% [markdown]
# We now have a complete DataSet to start modelling on.

# %%
df_w_rate
# Out:
#         symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 0         AAPL                      410825.300                  1.934379e+06
# 1          BAC                      133155.300                  4.429320e+05
# 2         AMZN                       16052.580                  3.881314e+05
# 3            T                       58268.480                  7.050311e+05
# 4           MO                     -155641.000                  3.219231e+06
# ...        ...                             ...                           ...
# 8642  IMMOU.BR                     -837823.155                  1.760240e+06
# 8643   BREB.BR                     -742811.212                  3.054464e+06
# 8644    NEU.BR                     -900450.812                  5.039275e+05
# 8645   PROX.BR                       29784.970                  4.283869e+05
# 8646   TEXF.BR                     -251954.217                  2.632529e+05
#
#       metric.receivablesTurnoverAnnual  \
# 0                            11.284440
# 1                             7.973046
# 2                            15.074940
# 3                             6.973920
# 4                           170.816300
# ...                                ...
# 8642                         12.043480
# 8643                        232.616169
# 8644                          9.350430
# 8645                          5.106880
# 8646                         22.760760
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 0                                   19.40911
# 1                                   29.93606
# 2                                    6.57306
# 3                                    5.05381
# 4                                    3.70202
# ...                                      ...
# 8642                                 4.81754
# 8643                                -3.03933
# 8644                               -39.89987
# 8645                                 0.05188
# 8646                                 4.94381
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 0                                    18.63398             38.718250
# 1                                    61.20183             53.779052
# 2                                     7.71885             38.289440
# 3                                     7.91697             53.188140
# 4                                     6.06133             47.072970
# ...                                       ...                   ...
# 8642                                 47.59596             84.209640
# 8643                                 -0.16750             83.706727
# 8644                               -169.99190             24.898900
# 8645                                  1.38347             62.201700
# 8646                                 25.43451             47.208966
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 0                    37.817770                       21.23809
# 1                    55.803548                       30.06225
# 2                    40.990010                        4.13586
# 3                    53.562780                        8.26467
# 4                    50.629230                       -4.83473
# ...                        ...                            ...
# 8642                 84.556760                       39.95187
# 8643                 69.051152                      106.46740
# 8644                 19.561240                      -76.23400
# 8645                 64.207170                        6.95282
# 8646                 48.544562                       49.75335
#
#       metric.netProfitMargin5Y  ...  metric.capitalSpendingGrowth5Y  \
# 0                     21.89832  ...                        1.352890
# 1                     25.11008  ...                       11.858569
# 2                      2.87305  ...                       28.074190
# 3                      8.60255  ...                       -1.722560
# 4                     25.37806  ...                        8.579920
# ...                        ...  ...                             ...
# 8642                  47.65050  ...                      -47.469440
# 8643                 106.24440  ...                       -6.095750
# 8644                 -10.26382  ...                       35.637490
# 8645                   8.72242  ...                        2.784790
# 8646                  40.47186  ...                       -7.603030
#
#       metric.inventoryTurnoverAnnual                                   Name  \
# 0                          40.134460                             Apple Inc.
# 1                           9.623854            Bank of America Corporation
# 2                           8.788510                       Amazon.com, Inc.
# 3                          29.863710                              AT&T Inc.
# 4                           5.362020                     Altria Group, Inc.
# ...                              ...                                    ...
# 8642                      142.318809                         Immo Moury SCA
# 8643                       14.805530                           Brederode SA
# 8644                        0.169430  Compagnie Financière de Neufcour S.A.
# 8645                       15.404580                           Proximus PLC
# 8646                       22.795993                            Texaf, S.A.
#
#       Exchange                    Category Name  Country  country  ccy  \
# 0          NMS             Electronic Equipment      USA      USA  USD
# 1          NYQ               Money Center Banks      USA      USA  USD
# 2          NMS      Catalog & Mail Order Houses      USA      USA  USD
# 3          NYQ      Telecom Services - Domestic      USA      USA  USD
# 4          NYQ                       Cigarettes      USA      USA  USD
# ...        ...                              ...      ...      ...  ...
# 8642       BRU              Property Management  Belgium  Belgium  EUR
# 8643       BRU                 Asset Management  Belgium  Belgium  EUR
# 8644       BRU              Property Management  Belgium  Belgium  EUR
# 8645       BRU  Information Technology Services  Belgium  Belgium  EUR
# 8646       BRU                    Conglomerates  Belgium  Belgium  EUR
#
#       ref_ccy  rate_vs_usd
# 0         USD     1.000000
# 1         USD     1.000000
# 2         USD     1.000000
# 3         USD     1.000000
# 4         USD     1.000000
# ...       ...          ...
# 8642      USD     0.920217
# 8643      USD     0.920217
# 8644      USD     0.920217
# 8645      USD     0.920217
# 8646      USD     0.920217
#
# [8647 rows x 36 columns]

# %%
Xalt = df_w_rate.iloc[:,1:28]
plt.figure(figsize = [25,25])
corr = sns.heatmap(Xalt.corr(), annot=True);
