# %% [markdown]
# # I. Relevant imports

# %%
from sklearn.impute import KNNImputer
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from forex_python.converter import CurrencyRates
from code_ref import usd_conv

# %% [markdown]
# # II.Data Cleaning

# %% [markdown]
# Loading main dataset resulting from API pull

# %%
findata = pd.read_csv('metric_final_set.csv')

# %% [markdown]
# Some primary feature selection - we are looking to simplify the dimensionality of the dataset and focus on key investment features
#
#  - This list is not exhaustive and may have some selection bias. We believe these metrics can lead us to extract information from company clusters.

# %%
findata1 = findata[['symbol','metric.netIncomeEmployeeAnnual', 'metric.revenueEmployeeAnnual','metric.receivablesTurnoverAnnual','metric.freeOperatingCashFlow/revenue5Y',
"metric.freeOperatingCashFlow/revenueTTM", 'metric.grossMargin5Y', 'metric.grossMarginAnnual',
'metric.netProfitMargin%Annual',
'metric.netProfitMargin5Y',
'metric.dividendGrowthRate5Y',
'metric.focfCagr5Y',
'metric.revenueGrowth5Y',
'metric.totalDebtCagr5Y',
'metric.netDebtAnnual',
'metric.peNormalizedAnnual',
'metric.pfcfShareAnnual',
'metric.currentEv/freeCashFlowAnnual',
'metric.freeCashFlowAnnual',
'metric.longTermDebt/equityAnnual',
'metric.netInterestCoverageAnnual',
'metric.payoutRatioAnnual',
'metric.quickRatioAnnual',
'metric.totalDebt/totalEquityAnnual',
'metric.dividendYield5Y',
'metric.dividendYieldIndicatedAnnual',
'metric.capitalSpendingGrowth5Y',
'metric.inventoryTurnoverAnnual',
]]

findata1.shape
# Out:
# (8831, 28)

# %% [markdown]
# Preliminary data observation highlight a large number of null values

# %%
findata1.sample(n=10)
# Out:
#          symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 8811      SAA.L                        2297.638                      165292.9
# 3764      HTG.L                       11680.180                      270844.7
# 7248     CNEL.L                             NaN                           NaN
# 8524     PFB.TO                             NaN                           NaN
# 7960    0513.HK                       73432.020                      666113.3
# 7127  600688.SS                      240882.600                    10862900.0
# 2259       CRVL                       11996.880                      154898.6
# 7398   MLEAS.PA                             NaN                           NaN
# 6736    0057.HK                       37178.750                      681640.8
# 3425     OXIG.L                       17820.550                      207140.6
#
#       metric.receivablesTurnoverAnnual  \
# 8811                           3.64364
# 3764                           5.08205
# 7248                           1.49108
# 8524                          11.18281
# 7960                           3.89172
# 7127                          41.62823
# 2259                           8.74314
# 7398                          36.17155
# 6736                           1.89290
# 3425                           5.10092
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 8811                                 2.41732
# 3764                                 4.31021
# 7248                                -3.35174
# 8524                                 1.99805
# 7960                                -9.86133
# 7127                                 3.41580
# 2259                                 6.55088
# 7398                                     NaN
# 6736                                -0.83898
# 3425                                 5.00460
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 8811                                  0.14410                   NaN
# 3764                                  8.33333              24.95985
# 7248                                 -9.13157              26.80611
# 8524                                  4.72184              23.54703
# 7960                                 -0.77484              17.87892
# 7127                                  0.91607              10.53989
# 2259                                  7.43286              20.28363
# 7398                                      NaN                   NaN
# 6736                                 15.27471              22.82159
# 3425                                  7.31085              49.09537
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 8811                  59.81603                        1.39004
# 3764                  27.75000                        4.31250
# 7248                  29.04416                       18.33001
# 8524                  26.14087                        6.77465
# 7960                  24.72861                       11.02395
# 7127                   5.81571                        2.21748
# 2259                  20.95025                        7.74499
# 7398                  17.88317                       -0.15038
# 6736                  21.61476                        5.45430
# 3425                  50.05995                        8.60312
#
#       metric.netProfitMargin5Y  ...  metric.freeCashFlowAnnual  \
# 8811                   1.99524  ...                   -5.02700
# 3764                  -6.60001  ...                   64.55760
# 7248                   8.66091  ...                   -0.14483
# 8524                   4.79972  ...                    6.29100
# 7960                  17.03820  ...                  -65.92900
# 7127                   4.99219  ...                  922.50400
# 2259                   6.19464  ...                   63.36500
# 7398                       NaN  ...                   -0.16756
# 6736                   1.16209  ...                    4.29900
# 3425                   1.44741  ...                   26.70000
#
#       metric.longTermDebt/equityAnnual  metric.netInterestCoverageAnnual  \
# 8811                          50.32382                               NaN
# 3764                           3.25358                               NaN
# 7248                           0.00000                          41.36381
# 8524                          29.71569                          11.96652
# 7960                           0.00000                               NaN
# 7127                           0.03545                               NaN
# 2259                           0.00000                               NaN
# 7398                               NaN                               NaN
# 6736                           0.00000                               NaN
# 3425                          16.76558                           9.34091
#
#       metric.payoutRatioAnnual  metric.quickRatioAnnual  \
# 8811                 267.83890                      NaN
# 3764                  45.84383                  2.28011
# 7248                   0.00000                  1.22354
# 8524                 100.19940                  1.70032
# 7960                  78.19776                  0.87163
# 7127                  58.67318                  1.00485
# 2259                   0.00000                      NaN
# 7398                       NaN                  0.06013
# 6736                  48.88955                  2.73552
# 3425                  28.78776                  0.87640
#
#       metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# 8811                            68.68227                 2.49028
# 3764                             4.19737                 0.69632
# 7248                             9.20790                     NaN
# 8524                            32.46172                 3.02804
# 7960                            33.21477                     NaN
# 7127                             7.70794                 3.62860
# 2259                             0.00000                     NaN
# 7398                                 NaN                     NaN
# 6736                             2.68513                 2.10997
# 3425                            18.54599                 1.64915
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 8811                              8.47751                        14.55088
# 3764                              4.65211                       -16.42943
# 7248                                  NaN                         7.40800
# 8524                              3.95604                         0.04548
# 7960                              3.84615                        -2.82598
# 7127                              6.06796                         5.60032
# 2259                                  NaN                        -3.59673
# 7398                                  NaN                             NaN
# 6736                              4.33526                       -30.86062
# 3425                              0.89983                        -4.28649
#
#       metric.inventoryTurnoverAnnual
# 8811                             NaN
# 3764                         1.98455
# 7248                        20.38430
# 8524                         8.46996
# 7960                         1.05567
# 7127                        12.70699
# 2259                             NaN
# 7398                         5.18364
# 6736                         1.89206
# 3425                         3.12277
#
# [10 rows x 28 columns]

# %% [markdown]
# # III. Currency Conversion - Net Debt & Free Cash Flow

# %% [markdown]
# Net Debt / Free Cash Flow are in local CCY. We need to convert them into USD to include these features in the clusters.

# %%
tick_conv = pd.read_csv('tickers_final.csv')

# %%
conv = pd.merge(findata1, tick_conv, left_on = 'symbol', right_on = 'Ticker').drop(columns = ['Ticker', 'Unnamed: 0'])

# %%
conv.sample()
# Out:
#        symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 6765  0627.HK                             NaN                           NaN
#
#       metric.receivablesTurnoverAnnual  \
# 6765                               NaN
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 6765                                     NaN
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 6765                                      NaN                   NaN
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 6765                       NaN                            NaN
#
#       metric.netProfitMargin5Y  ...  metric.quickRatioAnnual  \
# 6765                       NaN  ...                  0.26464
#
#       metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# 6765                            246.5421                     NaN
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 6765                                  NaN                             NaN
#
#       metric.inventoryTurnoverAnnual                                    Name  \
# 6765                             NaN  U-RIGHT International Holdings Limited
#
#       Exchange               Category Name    Country
# 6765       HKG  Textile - Apparel Clothing  Hong Kong
#
# [1 rows x 32 columns]

# %%
country_ccy = pd.DataFrame(conv.Country.unique(), columns = ['country'])

# %%
mapping = {'USA': 'USD', 'Australia': 'AUD', 'Germany': 'EUR', 'France': 'EUR', 'Canada':'CAD',
           'United Kingdom': 'GBP', 'Norway': 'NOK', 'Sweden': 'SEK', 'Denmark': 'DKK', 'Singapore': 'SGD', 'Netherlands':'EUR', 'Hong Kong':'HKD', 'Spain': 'EUR', 'Italy':'EUR', 'Belgium': 'EUR'}

# %%
country_ccy['ccy'] = country_ccy.country.map((mapping))

# %%
country_ccy['ref_ccy'] = 'USD'

# %%
def usd_conv(row):
    c = CurrencyRates()
    return c.get_rate(row['ref_ccy'],row ['ccy'])

# %%
country_ccy['rate_vs_usd'] = country_ccy.apply(usd_conv, axis =1)
country_ccy
# Out:
#            country  ccy ref_ccy  rate_vs_usd
# 0              USA  USD     USD     1.000000
# 1        Australia  AUD     USD     1.605227
# 2          Germany  EUR     USD     0.920217
# 3           France  EUR     USD     0.920217
# 4           Canada  CAD     USD     1.404712
# 5   United Kingdom  GBP     USD     0.805788
# 6           Norway  NOK     USD    10.319591
# 7           Sweden  SEK     USD    10.072237
# 8          Denmark  DKK     USD     6.870065
# 9        Singapore  SGD     USD     1.424404
# 10     Netherlands  EUR     USD     0.920217
# 11       Hong Kong  HKD     USD     7.753658
# 12           Spain  EUR     USD     0.920217
# 13           Italy  EUR     USD     0.920217
# 14         Belgium  EUR     USD     0.920217

# %%
df_w_rate = pd.merge(conv, country_ccy, left_on = 'Country', right_on = 'country')
df_w_rate[['metric.freeCashFlowAnnual','metric.netDebtAnnual', 'metric.revenueEmployeeAnnual', 'metric.NetIncomeEmployeeAnnual']] = df_w_rate[['metric.freeCashFlowAnnual','metric.netDebtAnnual','metric.revenueEmployeeAnnual', 'metric.netIncomeEmployeeAnnual']].divide(df_w_rate['rate_vs_usd'], axis = 0)

# %%
df_w_rate.sample(n=10)
# Out:
#        symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 7023   L03.SI                             NaN                           NaN
# 3634   BCI.AX                             NaN                           NaN
# 3475   IBG.AX                             NaN                           NaN
# 8003  3330.HK                      -225371.50                  9.323709e+04
# 2672     XBIT                     11528090.00                           NaN
# 1685     PCYG                        51687.55                  2.803922e+05
# 1781     SIGM                      -220477.40                  1.169565e+05
# 2304     PICO                       743612.90                  1.896645e+06
# 3478   AAC.AX                      -289553.20                  4.425555e+05
# 7627  0179.HK                        57566.38                  8.408133e+04
#
#       metric.receivablesTurnoverAnnual  \
# 7023                           2.38518
# 3634                           3.82391
# 3475                           3.26582
# 8003                           8.46238
# 2672                               NaN
# 1685                           2.89460
# 1781                           4.43790
# 2304                               NaN
# 3478                          22.24618
# 7627                           5.24992
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 7023                                 3.68829
# 3634                               -28.21488
# 3475                             -1731.40100
# 8003                                -0.00430
# 2672                                     NaN
# 1685                                 6.09329
# 1781                                -8.03384
# 2304                              -168.09660
# 3478                               -10.53473
# 7627                                 1.17460
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 7023                                 15.90319              17.86793
# 3634                                 -2.79733              14.81948
# 3475                              -1659.16700                   NaN
# 8003                                -13.95183               8.24274
# 2672                                      NaN                   NaN
# 1685                                 14.54601              69.63230
# 1781                                -60.23822              47.35912
# 2304                                 53.06824              71.03454
# 3478                                 -9.67030             -17.31978
# 7627                                  3.99795              25.70327
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 7023                  21.14501                        9.86941
# 3634                  19.31491                       23.47385
# 3475                       NaN                     -950.38760
# 8003                   4.38598                      -31.17480
# 2672                       NaN                            NaN
# 1685                  72.46014                       18.43402
# 1781                  37.11251                     -188.51230
# 2304                  71.10348                       39.20675
# 3478                 -31.14911                      -40.75906
# 7627                  22.90728                        8.83004
#
#       metric.netProfitMargin5Y  ...  metric.inventoryTurnoverAnnual  \
# 7023                  19.42770  ...                         3.39887
# 3634                 -42.04932  ...                             NaN
# 3475               -6556.88400  ...                             NaN
# 8003                  -7.46893  ...                         3.00740
# 2672                       NaN  ...                             NaN
# 1685                   8.80295  ...                             NaN
# 1781                 -29.64240  ...                         2.57341
# 2304                 -80.96863  ...                         1.98342
# 3478                  -5.05146  ...                         1.91431
# 7627                   8.87659  ...                         6.33298
#
#                                          Name  Exchange  \
# 7023                      Lian Beng Group Ltd       SES
# 3634                          BC Iron Limited       ASX
# 3475                    Ironbark Zinc Limited       ASX
# 8003                             LINGBAO GOLD       HKG
# 2672                            XBiotech Inc.       NMS
# 1685                    Park City Group, Inc.       NCM
# 1781                      Sigma Designs, Inc.       NMS
# 2304                      PICO Holdings, Inc.       NMS
# 3478  Australian Agricultural Company Limited       ASX
# 7627                           JOHNSON ELEC H       HKG
#
#                      Category Name    Country    country  ccy  ref_ccy  \
# 7023           General Contractors  Singapore  Singapore  SGD      USD
# 3634                  Steel & Iron  Australia  Australia  AUD      USD
# 3475                          Gold  Australia  Australia  AUD      USD
# 8003  Industrial Metals & Minerals  Hong Kong  Hong Kong  HKD      USD
# 2672                 Biotechnology        USA        USA  USD      USD
# 1685  Business Software & Services        USA        USA  USD      USD
# 1781   Semiconductor - Specialized        USA        USA  USD      USD
# 2304                 Conglomerates        USA        USA  USD      USD
# 3478                 Farm Products  Australia  Australia  AUD      USD
# 7627         Diversified Machinery  Hong Kong  Hong Kong  HKD      USD
#
#       rate_vs_usd  metric.NetIncomeEmployeeAnnual
# 7023     1.424404                             NaN
# 3634     1.605227                             NaN
# 3475     1.605227                             NaN
# 8003     7.753658                   -2.906647e+04
# 2672     1.000000                    1.152809e+07
# 1685     1.000000                    5.168755e+04
# 1781     1.000000                   -2.204774e+05
# 2304     1.000000                    7.436129e+05
# 3478     1.605227                   -1.803815e+05
# 7627     7.753658                    7.424416e+03
#
# [10 rows x 37 columns]

# %%
df_w_rate.shape
# Out:
# (8647, 37)

# %% [markdown]
# # IV. KNN Imputation

# %% [markdown]
#    - We elected KNNImputer to fill in missing values with the rationale that similar companies in terms of ratios would be grouped within the matrix dimensions and provide accurate inputs that would not affect the clustering outcomes. 20 nearest neighbors should preserve the accuracy of the data and avoid adding too much variance to the data.

# %%
Xalt = df_w_rate.iloc[:,1:28]

# %%
imputer = KNNImputer(n_neighbors = 20)
complete1 = imputer.fit_transform(Xalt)

# %%
df = pd.DataFrame(complete1, index = [df_w_rate.index, df_w_rate.iloc[:,0]], columns = Xalt.columns).reset_index()
df.drop(columns = ['level_0'], inplace = True)

# %% [markdown]
# We now have a complete DataSet to start modelling on.

# %%
df.sample(n=10)
# Out:
#       symbol  metric.netIncomeEmployeeAnnual  metric.revenueEmployeeAnnual  \
# 1514     CCO                   -6.184222e+04                  4.587709e+05
# 1466    CHMI                   -7.268926e+03                  1.494609e+06
# 3514  AGD.AX                    4.220933e+04                  3.757270e+05
# 364     PRTS                   -3.326094e+04                  2.958956e+05
# 1237      MX                   -8.790173e+03                  3.190475e+05
# 1628    CRCM                    1.121739e+05                  4.077625e+05
# 4190  TBR.AX                   -1.030837e+06                  3.263486e+05
# 3654  RTR.AX                   -8.993646e+05                  6.120166e+04
# 1571    MFNC                    4.555921e+04                  1.969079e+05
# 6908  G20.SI                    6.447113e+04                  3.153927e+05
#
#       metric.receivablesTurnoverAnnual  \
# 1514                          3.790710
# 1466                          0.500770
# 3514                         12.781720
# 364                          87.760160
# 1237                          6.999520
# 1628                         17.734530
# 4190                     701653.800000
# 3654                          0.312550
# 1571                          6.278979
# 6908                          7.470930
#
#       metric.freeOperatingCashFlow/revenue5Y  \
# 1514                               -8.121940
# 1466                               37.262730
# 3514                                2.433995
# 364                                 1.394610
# 1237                               -1.413870
# 1628                                3.963490
# 4190                                1.986240
# 3654                            -8943.738000
# 1571                               12.713210
# 6908                               -4.537850
#
#       metric.freeOperatingCashFlow/revenueTTM  metric.grossMargin5Y  \
# 1514                                 -0.69595             46.248500
# 1466                                171.16440             32.253580
# 3514                                 16.46430             41.663139
# 364                                   0.22697             29.150540
# 1237                                  3.33744             24.198140
# 1628                                  7.92930             79.435290
# 4190                                -93.45002             60.237300
# 3654                             -10625.80000          -1534.923314
# 1571                                 -1.19612             38.743015
# 6908                                 -6.57244             24.908480
#
#       metric.grossMarginAnnual  metric.netProfitMargin%Annual  \
# 1514                 45.891210                      -13.47998
# 1466               -313.010000                     -244.44200
# 3514                 45.902020                        1.60358
# 364                  30.009230                      -11.24077
# 1237                 22.798810                       -2.75513
# 1628                 77.787370                       27.50962
# 4190                 54.910790                       19.80597
# 3654               -473.160751                    -4535.24500
# 1571                 35.959853                       23.13732
# 6908                 24.989760                        3.94365
#
#       metric.netProfitMargin5Y  ...  metric.freeCashFlowAnnual  \
# 1514                 -9.883150  ...                 -18.678000
# 1466                 30.712420  ...                  30.457000
# 3514                 -0.134006  ...                  17.301978
# 364                   0.214360  ...                   0.637000
# 1237                 -1.948770  ...                  26.439000
# 1628                  0.733120  ...                  31.867000
# 4190                 24.867520  ...                   4.514321
# 3654             -10411.730000  ...                  -2.139872
# 1571                 17.808240  ...                  -0.716000
# 6908                  3.647350  ...                 -49.627769
#
#       metric.longTermDebt/equityAnnual  metric.netInterestCoverageAnnual  \
# 1514                        286.057457                          0.615470
# 1466                         40.860780                          8.426740
# 3514                         14.769700                          4.853080
# 364                          78.247170                         -2.905640
# 1237                        117.522489                          0.751110
# 1628                          0.000000                         56.689320
# 4190                          1.060990                        130.954900
# 3654                          0.000000                       -771.054758
# 1571                          0.200720                         63.687166
# 6908                         48.404670                         28.503027
#
#       metric.payoutRatioAnnual  metric.quickRatioAnnual  \
# 1514                 51.205064                 1.000210
# 1466                 91.975105                 0.662029
# 3514                 33.712094                 0.692680
# 364                  54.227750                 0.164700
# 1237                 43.224530                 2.287160
# 1628                  0.000000                 2.630950
# 4190                 49.393210                 1.081460
# 3654                 27.561162                 4.134477
# 1571                 40.259930                 3.246904
# 6908                 58.119830                 0.847720
#
#       metric.totalDebt/totalEquityAnnual  metric.dividendYield5Y  \
# 1514                          354.422443                3.780906
# 1466                          612.860700               11.931320
# 3514                           30.720420                2.603884
# 364                            89.305330                2.427613
# 1237                          146.261357                3.284836
# 1628                            0.000000                2.206504
# 4190                            2.965040                2.491173
# 3654                            0.000000                2.921830
# 1571                            4.093400                3.098510
# 6908                          135.686200                4.928880
#
#       metric.dividendYieldIndicatedAnnual  metric.capitalSpendingGrowth5Y  \
# 1514                             6.261765                        0.032980
# 1466                            19.656020                        6.540743
# 3514                             5.998686                       -8.700971
# 364                             12.774955                        1.365920
# 1237                             5.539539                        5.535110
# 1628                             5.502701                       -8.716800
# 4190                             4.970096                       19.027760
# 3654                             5.598942                       -2.441142
# 1571                             5.622490                       13.816630
# 6908                             6.382980                       15.532330
#
#       metric.inventoryTurnoverAnnual
# 1514                       74.122810
# 1466                       18.724152
# 3514                        4.537790
# 364                         3.846900
# 1237                        8.442740
# 1628                       16.936288
# 4190                        0.957990
# 3654                       26.032788
# 1571                       22.783812
# 6908                        4.800840
#
# [10 rows x 28 columns]

# %%
df.to_csv('clean_data.csv')

# %%
plt.figure(figsize = [25,25])
corr = df.iloc[:,1:28].corr().round(3)
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cl621_corr = sns.heatmap(corr, mask = mask, annot=True, linewidths = .5);
# plt.savefig('visualizations/clean_data_corr_hm.png')
